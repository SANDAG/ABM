# %% [markdown]
# # Estimating Stop Frequency
#
# This notebook illustrates how to re-estimate a single model component for ActivitySim.  This process
# includes running ActivitySim in estimation mode to read household travel survey files and write out
# the estimation data bundles used in this notebook.  To review how to do so, please visit the other
# notebooks in this directory.

# %% [markdown]
# # Load libraries

# %%
import os
import larch  # !conda install larch -c conda-forge # for estimation
import pandas as pd

# %% [markdown]
# We'll work in our `test` directory, where ActivitySim has saved the estimation data bundles.

# %%
os.chdir('test')

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname = "stop_frequency"

from activitysim.estimation.larch import component_model
model, data = component_model(modelname, return_data=True)
# Out:
# C:\Anaconda3\envs\asimtest\lib\site-packages\activitysim\estimation\larch\general.py:321: UserWarning: coefficient dataframe missing 'constrain' column, setting all to 'F'
#   warnings.warn("coefficient dataframe missing 'constrain' column, setting all to 'F'")

# %% [markdown]
# # Review data loaded from the EDB
#
# The next step is to read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %%
spec_segments = [i.primary_purpose for i in data.settings.SPEC_SEGMENTS]
spec_segments
# Out:
# ['work', 'school', 'visit', 'shop', 'other', 'cargo']

# %% [markdown]
# ## Coefficients
#
# There is one meta-coefficients dataframe for this component, which contains
# parameters for all the matching coefficients in the various segmented
# files. When different segments have the same named coefficient with the same
# value, it is assumed they should be estimated jointly.  If they have the same name
# but different values in the coefficient files, then they are re-estimated
# independently.

# %% [markdown]
# Set coefficients to 0 to start

# %%
data.coefficients
# Out:
#                                   value constrain
# coefficient_name
# coef_asc_dur_0_4_stops_0out_0in       0         F
# coef_asc_dur_0_4_stops_0out_1in       0         F
# coef_asc_dur_0_4_stops_0out_2in       0         F
# coef_asc_dur_0_4_stops_0out_3in       0         F
# coef_asc_dur_0_4_stops_1out_0in       0         F
# coef_asc_dur_0_4_stops_1out_1in       0         F
# coef_asc_dur_0_4_stops_1out_2in       0         F
# coef_asc_dur_0_4_stops_1out_3in       0         F
# coef_asc_dur_0_4_stops_2out_0in       0         F
# coef_asc_dur_0_4_stops_2out_1in       0         F
# coef_asc_dur_0_4_stops_2out_2in       0         F
# coef_asc_dur_0_4_stops_2out_3in       0         F
# coef_asc_dur_0_4_stops_3out_0in       0         F
# coef_asc_dur_0_4_stops_3out_1in       0         F
# coef_asc_dur_0_4_stops_3out_2in       0         F
# coef_asc_dur_0_4_stops_3out_3in       0         F
# coef_asc_dur_4_8_stops_0out_0in       0         F
# coef_asc_dur_4_8_stops_0out_1in       0         F
# coef_asc_dur_4_8_stops_0out_2in       0         F
# coef_asc_dur_4_8_stops_0out_3in       0         F
# coef_asc_dur_4_8_stops_1out_0in       0         F
# coef_asc_dur_4_8_stops_1out_1in       0         F
# coef_asc_dur_4_8_stops_1out_2in       0         F
# coef_asc_dur_4_8_stops_1out_3in       0         F
# coef_asc_dur_4_8_stops_2out_0in       0         F
# coef_asc_dur_4_8_stops_2out_1in       0         F
# coef_asc_dur_4_8_stops_2out_2in       0         F
# coef_asc_dur_4_8_stops_2out_3in       0         F
# coef_asc_dur_4_8_stops_3out_0in       0         F
# coef_asc_dur_4_8_stops_3out_1in       0         F
# coef_asc_dur_4_8_stops_3out_2in       0         F
# coef_asc_dur_4_8_stops_3out_3in       0         F
# coef_asc_dur_8_24_stops_0out_0in      0         F
# coef_asc_dur_8_24_stops_0out_1in      0         F
# coef_asc_dur_8_24_stops_0out_2in      0         F
# coef_asc_dur_8_24_stops_0out_3in      0         F
# coef_asc_dur_8_24_stops_1out_0in      0         F
# coef_asc_dur_8_24_stops_1out_1in      0         F
# coef_asc_dur_8_24_stops_1out_2in      0         F
# coef_asc_dur_8_24_stops_1out_3in      0         F
# coef_asc_dur_8_24_stops_2out_0in      0         F
# coef_asc_dur_8_24_stops_2out_1in      0         F
# coef_asc_dur_8_24_stops_2out_2in      0         F
# coef_asc_dur_8_24_stops_2out_3in      0         F
# coef_asc_dur_8_24_stops_3out_0in      0         F
# coef_asc_dur_8_24_stops_3out_1in      0         F
# coef_asc_dur_8_24_stops_3out_2in      0         F
# coef_asc_dur_8_24_stops_3out_3in      0         F

# %% [markdown]
# ## Utility specification
#
# The utility spec files are unique to each segment model.  The estimation mode larch pre-processor
# for the stop frequency model modifies the spec files to account for jointly re-estimated
# parameters.

# %%
data.spec[0]
# Out:
#                     Label                              Description  \
# 0   util_ASC_tour_dur_0_4   ASC for tour durations between 0 and 4
# 1   util_ASC_tour_dur_4_8   ASC for tour durations between 4 and 8
# 2  util_ASC_tour_dur_8_24  ASC for tour durations between 8 and 24
#
#                  Expression  0out_0in                          0out_1in  \
# 0   0 < duration_hours <= 4         0   coef_asc_dur_0_4_stops_0out_1in
# 1   4 < duration_hours <= 8         0   coef_asc_dur_4_8_stops_0out_1in
# 2  8 < duration_hours <= 24         0  coef_asc_dur_8_24_stops_0out_1in
#
#                            0out_2in                          0out_3in  \
# 0   coef_asc_dur_0_4_stops_0out_2in   coef_asc_dur_0_4_stops_0out_3in
# 1   coef_asc_dur_4_8_stops_0out_2in   coef_asc_dur_4_8_stops_0out_3in
# 2  coef_asc_dur_8_24_stops_0out_2in  coef_asc_dur_8_24_stops_0out_3in
#
#                            1out_0in                          1out_1in  \
# 0   coef_asc_dur_0_4_stops_1out_0in   coef_asc_dur_0_4_stops_1out_1in
# 1   coef_asc_dur_4_8_stops_1out_0in   coef_asc_dur_4_8_stops_1out_1in
# 2  coef_asc_dur_8_24_stops_1out_0in  coef_asc_dur_8_24_stops_1out_1in
#
#                            1out_2in                          1out_3in  \
# 0   coef_asc_dur_0_4_stops_1out_2in   coef_asc_dur_0_4_stops_1out_3in
# 1   coef_asc_dur_4_8_stops_1out_2in   coef_asc_dur_4_8_stops_1out_3in
# 2  coef_asc_dur_8_24_stops_1out_2in  coef_asc_dur_8_24_stops_1out_3in
#
#                            2out_0in                          2out_1in  \
# 0   coef_asc_dur_0_4_stops_2out_0in   coef_asc_dur_0_4_stops_2out_1in
# 1   coef_asc_dur_4_8_stops_2out_0in   coef_asc_dur_4_8_stops_2out_1in
# 2  coef_asc_dur_8_24_stops_2out_0in  coef_asc_dur_8_24_stops_2out_1in
#
#                            2out_2in                          2out_3in  \
# 0   coef_asc_dur_0_4_stops_2out_2in   coef_asc_dur_0_4_stops_2out_3in
# 1   coef_asc_dur_4_8_stops_2out_2in   coef_asc_dur_4_8_stops_2out_3in
# 2  coef_asc_dur_8_24_stops_2out_2in  coef_asc_dur_8_24_stops_2out_3in
#
#                            3out_0in                          3out_1in  \
# 0   coef_asc_dur_0_4_stops_3out_0in   coef_asc_dur_0_4_stops_3out_1in
# 1   coef_asc_dur_4_8_stops_3out_0in   coef_asc_dur_4_8_stops_3out_1in
# 2  coef_asc_dur_8_24_stops_3out_0in  coef_asc_dur_8_24_stops_3out_1in
#
#                            3out_2in                          3out_3in
# 0   coef_asc_dur_0_4_stops_3out_2in   coef_asc_dur_0_4_stops_3out_3in
# 1   coef_asc_dur_4_8_stops_3out_2in   coef_asc_dur_4_8_stops_3out_3in
# 2  coef_asc_dur_8_24_stops_3out_2in  coef_asc_dur_8_24_stops_3out_3in

# %% [markdown]
# ## Chooser data
#
# The chooser data is unique to each segment model.

# %%
data.chooser_data[0]
# Out:
#         model_choice override_choice  util_ASC_tour_dur_0_4  \
# tour_id
# 618         0out_0in        0out_0in                    0.0
# 950         1out_2in        1out_2in                    0.0
# 1138        0out_0in        1out_0in                    0.0
# 1190        0out_0in        0out_1in                    0.0
# 1191        0out_1in        1out_2in                    0.0
# ...              ...             ...                    ...
# 112081      1out_0in        3out_0in                    0.0
# 113034      0out_0in        0out_3in                    0.0
# 113224      0out_2in        0out_2in                    0.0
# 113541      0out_0in        0out_1in                    0.0
# 113901      0out_0in        0out_2in                    0.0
#
#          util_ASC_tour_dur_4_8  util_ASC_tour_dur_8_24  sentri_crossing  \
# tour_id
# 618                        0.0                     1.0                1
# 950                        0.0                     1.0                0
# 1138                       0.0                     1.0                0
# 1190                       0.0                     1.0                0
# 1191                       0.0                     1.0                0
# ...                        ...                     ...              ...
# 112081                     1.0                     0.0                0
# 113034                     0.0                     1.0                1
# 113224                     0.0                     1.0                0
# 113541                     1.0                     0.0                1
# 113901                     0.0                     1.0                1
#
#         lane_type  lane_id tour_type  purpose_id  ... ped_wait_26  \
# tour_id                                           ...
# 618           ped        3      work           0  ...        28.6
# 950           ped        3      work           0  ...         7.0
# 1138          ped        3      work           0  ...        28.6
# 1190        ready        2      work           0  ...        28.6
# 1191          ped        3      work           0  ...        28.6
# ...           ...      ...       ...         ...  ...         ...
# 112081    regular        0      work           0  ...         7.0
# 113034        ped        3      work           0  ...        28.6
# 113224        ped        3      work           0  ...         7.0
# 113541        ped        3      work           0  ...         7.0
# 113901        ped        3      work           0  ...        28.6
#
#          ped_wait_28  ped_wait_30  ped_wait_32  ped_wait_34  ped_wait_36  \
# tour_id
# 618             24.5         23.3         16.4         10.0          7.0
# 950              7.1          6.2          3.9          1.6          2.1
# 1138            24.5         23.3         16.4         10.0          7.0
# 1190            24.5         23.3         16.4         10.0          7.0
# 1191            24.5         23.3         16.4         10.0          7.0
# ...              ...          ...          ...          ...          ...
# 112081           7.1          6.2          3.9          1.6          2.1
# 113034          24.5         23.3         16.4         10.0          7.0
# 113224           7.1          6.2          3.9          1.6          2.1
# 113541           7.1          6.2          3.9          1.6          2.1
# 113901          24.5         23.3         16.4         10.0          7.0
#
#          ped_wait_38  ped_wait_40  primary_purpose  duration_hours
# tour_id
# 618              2.3          1.7             work            10.0
# 950              3.9          1.7             work            16.0
# 1138             2.3          1.7             work             9.0
# 1190             2.3          1.7             work             8.5
# 1191             2.3          1.7             work             8.5
# ...              ...          ...              ...             ...
# 112081           3.9          1.7             work             6.0
# 113034           2.3          1.7             work             9.0
# 113224           3.9          1.7             work            10.0
# 113541           3.9          1.7             work             7.5
# 113901           2.3          1.7             work             9.0
#
# [304 rows x 206 columns]

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.estimate(method='SLSQP', options={"maxiter": 1000})
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# req_data does not request avail_ca or avail_co but it is set and being provided
# <h3>Iteration 058 [Optimization terminated successfully] </h3>
# <p>Best LL = -2321.1720087663225</p>
#                                        value  initvalue  nullvalue  minimum  \
# 0                                   0.000000        0.0        0.0      0.0
# coef_asc_dur_0_4_stops_0out_1in    -0.606131        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_0out_2in    -2.397892        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_0out_3in    -2.397892        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_1out_0in    -0.606137        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_1out_1in    -1.299280        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_1out_2in    -1.704744        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_1out_3in    -2.397892        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_2out_0in    -0.788455        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_2out_1in  -347.352379        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_2out_2in  -347.352379        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_2out_3in  -347.352379        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_3out_0in    -1.704744        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_3out_1in  -347.352379        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_3out_2in  -347.352379        0.0        0.0      NaN
# coef_asc_dur_0_4_stops_3out_3in  -347.352379        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_0out_1in    -0.990398        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_0out_2in    -1.945910        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_0out_3in    -1.763589        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_1out_0in    -1.203972        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_1out_1in    -1.609438        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_1out_2in    -2.051271        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_1out_3in    -4.248501        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_2out_0in    -1.763589        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_2out_1in    -2.456736        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_2out_2in    -3.555348        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_2out_3in  -214.930215        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_3out_0in    -1.850600        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_3out_1in    -2.639057        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_3out_2in    -3.555348        0.0        0.0      NaN
# coef_asc_dur_4_8_stops_3out_3in  -214.930215        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_0out_1in   -0.698945        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_0out_2in   -0.933783        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_0out_3in   -1.392091        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_1out_0in   -0.609999        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_1out_1in   -1.656783        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_1out_2in   -1.934416        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_1out_3in   -2.208853        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_2out_0in   -0.933783        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_2out_1in   -1.752094        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_2out_2in   -3.361524        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_2out_3in   -3.361538        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_3out_0in   -1.439719        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_3out_1in   -1.010156        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_3out_2in  -18.899758        0.0        0.0      NaN
# coef_asc_dur_8_24_stops_3out_3in   -3.361534        0.0        0.0      NaN
#
#                                   maximum  holdfast note        best
# 0                                     0.0         1         0.000000
# coef_asc_dur_0_4_stops_0out_1in       NaN         0        -0.606131
# coef_asc_dur_0_4_stops_0out_2in       NaN         0        -2.397892
# coef_asc_dur_0_4_stops_0out_3in       NaN         0        -2.397892
# coef_asc_dur_0_4_stops_1out_0in       NaN         0        -0.606137
# coef_asc_dur_0_4_stops_1out_1in       NaN         0        -1.299280
# coef_asc_dur_0_4_stops_1out_2in       NaN         0        -1.704744
# coef_asc_dur_0_4_stops_1out_3in       NaN         0        -2.397892
# coef_asc_dur_0_4_stops_2out_0in       NaN         0        -0.788455
# coef_asc_dur_0_4_stops_2out_1in       NaN         0      -347.352379
# coef_asc_dur_0_4_stops_2out_2in       NaN         0      -347.352379
# coef_asc_dur_0_4_stops_2out_3in       NaN         0      -347.352379
# coef_asc_dur_0_4_stops_3out_0in       NaN         0        -1.704744
# coef_asc_dur_0_4_stops_3out_1in       NaN         0      -347.352379
# coef_asc_dur_0_4_stops_3out_2in       NaN         0      -347.352379
# coef_asc_dur_0_4_stops_3out_3in       NaN         0      -347.352379
# coef_asc_dur_4_8_stops_0out_1in       NaN         0        -0.990398
# coef_asc_dur_4_8_stops_0out_2in       NaN         0        -1.945910
# coef_asc_dur_4_8_stops_0out_3in       NaN         0        -1.763589
# coef_asc_dur_4_8_stops_1out_0in       NaN         0        -1.203972
# coef_asc_dur_4_8_stops_1out_1in       NaN         0        -1.609438
# coef_asc_dur_4_8_stops_1out_2in       NaN         0        -2.051271
# coef_asc_dur_4_8_stops_1out_3in       NaN         0        -4.248501
# coef_asc_dur_4_8_stops_2out_0in       NaN         0        -1.763589
# coef_asc_dur_4_8_stops_2out_1in       NaN         0        -2.456736
# coef_asc_dur_4_8_stops_2out_2in       NaN         0        -3.555348
# coef_asc_dur_4_8_stops_2out_3in       NaN         0      -214.930215
# coef_asc_dur_4_8_stops_3out_0in       NaN         0        -1.850600
# coef_asc_dur_4_8_stops_3out_1in       NaN         0        -2.639057
# coef_asc_dur_4_8_stops_3out_2in       NaN         0        -3.555348
# coef_asc_dur_4_8_stops_3out_3in       NaN         0      -214.930215
# coef_asc_dur_8_24_stops_0out_1in      NaN         0        -0.698945
# coef_asc_dur_8_24_stops_0out_2in      NaN         0        -0.933783
# coef_asc_dur_8_24_stops_0out_3in      NaN         0        -1.392091
# coef_asc_dur_8_24_stops_1out_0in      NaN         0        -0.609999
# coef_asc_dur_8_24_stops_1out_1in      NaN         0        -1.656783
# coef_asc_dur_8_24_stops_1out_2in      NaN         0        -1.934416
# coef_asc_dur_8_24_stops_1out_3in      NaN         0        -2.208853
# coef_asc_dur_8_24_stops_2out_0in      NaN         0        -0.933783
# coef_asc_dur_8_24_stops_2out_1in      NaN         0        -1.752094
# coef_asc_dur_8_24_stops_2out_2in      NaN         0        -3.361524
# coef_asc_dur_8_24_stops_2out_3in      NaN         0        -3.361538
# coef_asc_dur_8_24_stops_3out_0in      NaN         0        -1.439719
# coef_asc_dur_8_24_stops_3out_1in      NaN         0        -1.010156
# coef_asc_dur_8_24_stops_3out_2in      NaN         0       -18.899758
# coef_asc_dur_8_24_stops_3out_3in      NaN         0        -3.361534
# <ipython-input-20-c0c5a8a8ae55>:1: PossibleOverspecification: WARNING: Model is possibly over-specified (hessian is nearly singular).
#   model.estimate(method='SLSQP', options={"maxiter": 1000})
# C:\Anaconda3\envs\asimtest\lib\site-packages\larch\linalg\__init__.py:18: UserWarning: minimum eig 0.0 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# ┣                x: 0                                     0.000000
# ┃                   coef_asc_dur_0_4_stops_0out_1in      -0.606131
# ┃                   coef_asc_dur_0_4_stops_0out_2in      -2.397892
# ┃                   coef_asc_dur_0_4_stops_0out_3in      -2.397892
# ┃                   coef_asc_dur_0_4_stops_1out_0in      -0.606137
# ┃                   coef_asc_dur_0_4_stops_1out_1in      -1.299280
# ┃                   coef_asc_dur_0_4_stops_1out_2in      -1.704744
# ┃                   coef_asc_dur_0_4_stops_1out_3in      -2.397892
# ┃                   coef_asc_dur_0_4_stops_2out_0in      -0.788455
# ┃                   coef_asc_dur_0_4_stops_2out_1in    -347.352379
# ┃                   coef_asc_dur_0_4_stops_2out_2in    -347.352379
# ┃                   coef_asc_dur_0_4_stops_2out_3in    -347.352379
# ┃                   coef_asc_dur_0_4_stops_3out_0in      -1.704744
# ┃                   coef_asc_dur_0_4_stops_3out_1in    -347.352379
# ┃                   coef_asc_dur_0_4_stops_3out_2in    -347.352379
# ┃                   coef_asc_dur_0_4_stops_3out_3in    -347.352379
# ┃                   coef_asc_dur_4_8_stops_0out_1in      -0.990398
# ┃                   coef_asc_dur_4_8_stops_0out_2in      -1.945910
# ┃                   coef_asc_dur_4_8_stops_0out_3in      -1.763589
# ┃                   coef_asc_dur_4_8_stops_1out_0in      -1.203972
# ┃                   coef_asc_dur_4_8_stops_1out_1in      -1.609438
# ┃                   coef_asc_dur_4_8_stops_1out_2in      -2.051271
# ┃                   coef_asc_dur_4_8_stops_1out_3in      -4.248501
# ┃                   coef_asc_dur_4_8_stops_2out_0in      -1.763589
# ┃                   coef_asc_dur_4_8_stops_2out_1in      -2.456736
# ┃                   coef_asc_dur_4_8_stops_2out_2in      -3.555348
# ┃                   coef_asc_dur_4_8_stops_2out_3in    -214.930215
# ┃                   coef_asc_dur_4_8_stops_3out_0in      -1.850600
# ┃                   coef_asc_dur_4_8_stops_3out_1in      -2.639057
# ┃                   coef_asc_dur_4_8_stops_3out_2in      -3.555348
# ┃                   coef_asc_dur_4_8_stops_3out_3in    -214.930215
# ┃                   coef_asc_dur_8_24_stops_0out_1in     -0.698945
# ┃                   coef_asc_dur_8_24_stops_0out_2in     -0.933783
# ┃                   coef_asc_dur_8_24_stops_0out_3in     -1.392091
# ┃                   coef_asc_dur_8_24_stops_1out_0in     -0.609999
# ┃                   coef_asc_dur_8_24_stops_1out_1in     -1.656783
# ┃                   coef_asc_dur_8_24_stops_1out_2in     -1.934416
# ┃                   coef_asc_dur_8_24_stops_1out_3in     -2.208853
# ┃                   coef_asc_dur_8_24_stops_2out_0in     -0.933783
# ┃                   coef_asc_dur_8_24_stops_2out_1in     -1.752094
# ┃                   coef_asc_dur_8_24_stops_2out_2in     -3.361524
# ┃                   coef_asc_dur_8_24_stops_2out_3in     -3.361538
# ┃                   coef_asc_dur_8_24_stops_3out_0in     -1.439719
# ┃                   coef_asc_dur_8_24_stops_3out_1in     -1.010156
# ┃                   coef_asc_dur_8_24_stops_3out_2in    -18.899758
# ┃                   coef_asc_dur_8_24_stops_3out_3in     -3.361534
# ┃                   dtype: float64
# ┣          loglike: -2321.1720087663225
# ┣        d_loglike: 0                                    0.000000e+00
# ┃                   coef_asc_dur_0_4_stops_0out_1in     -1.548063e-05
# ┃                   coef_asc_dur_0_4_stops_0out_2in     -1.446878e-06
# ┃                   coef_asc_dur_0_4_stops_0out_3in     -1.446878e-06
# ┃                   coef_asc_dur_0_4_stops_1out_0in      1.697374e-05
# ┃                   coef_asc_dur_0_4_stops_1out_1in     -4.132370e-06
# ┃                   coef_asc_dur_0_4_stops_1out_2in     -3.690026e-06
# ┃                   coef_asc_dur_0_4_stops_1out_3in     -1.446878e-06
# ┃                   coef_asc_dur_0_4_stops_2out_0in     -4.861224e-06
# ┃                   coef_asc_dur_0_4_stops_2out_1in    -1.542306e-150
# ┃                   coef_asc_dur_0_4_stops_2out_2in    -1.542306e-150
# ┃                   coef_asc_dur_0_4_stops_2out_3in    -1.542306e-150
# ┃                   coef_asc_dur_0_4_stops_3out_0in     -3.799285e-06
# ┃                   coef_asc_dur_0_4_stops_3out_1in    -1.542306e-150
# ┃                   coef_asc_dur_0_4_stops_3out_2in    -1.542306e-150
# ┃                   coef_asc_dur_0_4_stops_3out_3in    -1.542306e-150
# ┃                   coef_asc_dur_4_8_stops_0out_1in     -1.653258e-05
# ┃                   coef_asc_dur_4_8_stops_0out_2in      2.548981e-06
# ┃                   coef_asc_dur_4_8_stops_0out_3in      3.462038e-06
# ┃                   coef_asc_dur_4_8_stops_1out_0in     -1.189623e-05
# ┃                   coef_asc_dur_4_8_stops_1out_1in      5.666129e-06
# ┃                   coef_asc_dur_4_8_stops_1out_2in      3.024946e-06
# ┃                   coef_asc_dur_4_8_stops_1out_3in      5.330361e-06
# ┃                   coef_asc_dur_4_8_stops_2out_0in      6.289987e-06
# ┃                   coef_asc_dur_4_8_stops_2out_1in     -6.574304e-07
# ┃                   coef_asc_dur_4_8_stops_2out_2in      3.602213e-07
# ┃                   coef_asc_dur_4_8_stops_2out_3in     -3.177544e-92
# ┃                   coef_asc_dur_4_8_stops_3out_0in      5.567781e-06
# ┃                   coef_asc_dur_4_8_stops_3out_1in     -2.041870e-06
# ┃                   coef_asc_dur_4_8_stops_3out_2in      3.433924e-07
# ┃                   coef_asc_dur_4_8_stops_3out_3in     -3.177544e-92
# ┃                   coef_asc_dur_8_24_stops_0out_1in     2.653675e-05
# ┃                   coef_asc_dur_8_24_stops_0out_2in    -3.953148e-05
# ┃                   coef_asc_dur_8_24_stops_0out_3in    -3.234860e-05
# ┃                   coef_asc_dur_8_24_stops_1out_0in     1.751874e-04
# ┃                   coef_asc_dur_8_24_stops_1out_1in    -3.770874e-05
# ┃                   coef_asc_dur_8_24_stops_1out_2in    -3.368224e-07
# ┃                   coef_asc_dur_8_24_stops_1out_3in     1.097625e-06
# ┃                   coef_asc_dur_8_24_stops_2out_0in    -4.133186e-05
# ┃                   coef_asc_dur_8_24_stops_2out_1in    -8.079254e-06
# ┃                   coef_asc_dur_8_24_stops_2out_2in    -4.626347e-05
# ┃                   coef_asc_dur_8_24_stops_2out_3in     3.736921e-05
# ┃                   coef_asc_dur_8_24_stops_3out_0in    -2.561835e-05
# ┃                   coef_asc_dur_8_24_stops_3out_1in    -3.412453e-05
# ┃                   coef_asc_dur_8_24_stops_3out_2in    -1.071484e-06
# ┃                   coef_asc_dur_8_24_stops_3out_3in     1.216921e-05
# ┃                   dtype: float64
# ┣              nit: 58
# ┣             nfev: 101
# ┣             njev: 58
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=22, microseconds=870405)
# ┣           method: 'SLSQP'
# ┣          n_cases: 1000
# ┣ iteration_number: 58
# ┣          logloss: 2.3211720087663226

# %% [markdown]
# ### Estimated coefficients

# %%
model.parameter_summary()
# Out:
# <style type="text/css">
# #T_1bf5d_ th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_1bf5d_ td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_1bf5d_row0_col0, #T_1bf5d_row0_col1, #T_1bf5d_row0_col2, #T_1bf5d_row0_col3, #T_1bf5d_row0_col4, #T_1bf5d_row0_col5, #T_1bf5d_row1_col0, #T_1bf5d_row1_col1, #T_1bf5d_row1_col2, #T_1bf5d_row1_col3, #T_1bf5d_row1_col4, #T_1bf5d_row1_col5, #T_1bf5d_row2_col0, #T_1bf5d_row2_col1, #T_1bf5d_row2_col2, #T_1bf5d_row2_col3, #T_1bf5d_row2_col4, #T_1bf5d_row2_col5, #T_1bf5d_row3_col0, #T_1bf5d_row3_col1, #T_1bf5d_row3_col2, #T_1bf5d_row3_col3, #T_1bf5d_row3_col4, #T_1bf5d_row3_col5, #T_1bf5d_row4_col0, #T_1bf5d_row4_col1, #T_1bf5d_row4_col2, #T_1bf5d_row4_col3, #T_1bf5d_row4_col4, #T_1bf5d_row4_col5, #T_1bf5d_row5_col0, #T_1bf5d_row5_col1, #T_1bf5d_row5_col2, #T_1bf5d_row5_col3, #T_1bf5d_row5_col4, #T_1bf5d_row5_col5, #T_1bf5d_row6_col0, #T_1bf5d_row6_col1, #T_1bf5d_row6_col2, #T_1bf5d_row6_col3, #T_1bf5d_row6_col4, #T_1bf5d_row6_col5, #T_1bf5d_row7_col0, #T_1bf5d_row7_col1, #T_1bf5d_row7_col2, #T_1bf5d_row7_col3, #T_1bf5d_row7_col4, #T_1bf5d_row7_col5, #T_1bf5d_row8_col0, #T_1bf5d_row8_col1, #T_1bf5d_row8_col2, #T_1bf5d_row8_col3, #T_1bf5d_row8_col4, #T_1bf5d_row8_col5, #T_1bf5d_row9_col0, #T_1bf5d_row9_col1, #T_1bf5d_row9_col2, #T_1bf5d_row9_col3, #T_1bf5d_row9_col4, #T_1bf5d_row9_col5, #T_1bf5d_row10_col0, #T_1bf5d_row10_col1, #T_1bf5d_row10_col2, #T_1bf5d_row10_col3, #T_1bf5d_row10_col4, #T_1bf5d_row10_col5, #T_1bf5d_row11_col0, #T_1bf5d_row11_col1, #T_1bf5d_row11_col2, #T_1bf5d_row11_col3, #T_1bf5d_row11_col4, #T_1bf5d_row11_col5, #T_1bf5d_row12_col0, #T_1bf5d_row12_col1, #T_1bf5d_row12_col2, #T_1bf5d_row12_col3, #T_1bf5d_row12_col4, #T_1bf5d_row12_col5, #T_1bf5d_row13_col0, #T_1bf5d_row13_col1, #T_1bf5d_row13_col2, #T_1bf5d_row13_col3, #T_1bf5d_row13_col4, #T_1bf5d_row13_col5, #T_1bf5d_row14_col0, #T_1bf5d_row14_col1, #T_1bf5d_row14_col2, #T_1bf5d_row14_col3, #T_1bf5d_row14_col4, #T_1bf5d_row14_col5, #T_1bf5d_row15_col0, #T_1bf5d_row15_col1, #T_1bf5d_row15_col2, #T_1bf5d_row15_col3, #T_1bf5d_row15_col4, #T_1bf5d_row15_col5, #T_1bf5d_row16_col0, #T_1bf5d_row16_col1, #T_1bf5d_row16_col2, #T_1bf5d_row16_col3, #T_1bf5d_row16_col4, #T_1bf5d_row16_col5, #T_1bf5d_row17_col0, #T_1bf5d_row17_col1, #T_1bf5d_row17_col2, #T_1bf5d_row17_col3, #T_1bf5d_row17_col4, #T_1bf5d_row17_col5, #T_1bf5d_row18_col0, #T_1bf5d_row18_col1, #T_1bf5d_row18_col2, #T_1bf5d_row18_col3, #T_1bf5d_row18_col4, #T_1bf5d_row18_col5, #T_1bf5d_row19_col0, #T_1bf5d_row19_col1, #T_1bf5d_row19_col2, #T_1bf5d_row19_col3, #T_1bf5d_row19_col4, #T_1bf5d_row19_col5, #T_1bf5d_row20_col0, #T_1bf5d_row20_col1, #T_1bf5d_row20_col2, #T_1bf5d_row20_col3, #T_1bf5d_row20_col4, #T_1bf5d_row20_col5, #T_1bf5d_row21_col0, #T_1bf5d_row21_col1, #T_1bf5d_row21_col2, #T_1bf5d_row21_col3, #T_1bf5d_row21_col4, #T_1bf5d_row21_col5, #T_1bf5d_row22_col0, #T_1bf5d_row22_col1, #T_1bf5d_row22_col2, #T_1bf5d_row22_col3, #T_1bf5d_row22_col4, #T_1bf5d_row22_col5, #T_1bf5d_row23_col0, #T_1bf5d_row23_col1, #T_1bf5d_row23_col2, #T_1bf5d_row23_col3, #T_1bf5d_row23_col4, #T_1bf5d_row23_col5, #T_1bf5d_row24_col0, #T_1bf5d_row24_col1, #T_1bf5d_row24_col2, #T_1bf5d_row24_col3, #T_1bf5d_row24_col4, #T_1bf5d_row24_col5, #T_1bf5d_row25_col0, #T_1bf5d_row25_col1, #T_1bf5d_row25_col2, #T_1bf5d_row25_col3, #T_1bf5d_row25_col4, #T_1bf5d_row25_col5, #T_1bf5d_row26_col0, #T_1bf5d_row26_col1, #T_1bf5d_row26_col2, #T_1bf5d_row26_col3, #T_1bf5d_row26_col4, #T_1bf5d_row26_col5, #T_1bf5d_row27_col0, #T_1bf5d_row27_col1, #T_1bf5d_row27_col2, #T_1bf5d_row27_col3, #T_1bf5d_row27_col4, #T_1bf5d_row27_col5, #T_1bf5d_row28_col0, #T_1bf5d_row28_col1, #T_1bf5d_row28_col2, #T_1bf5d_row28_col3, #T_1bf5d_row28_col4, #T_1bf5d_row28_col5, #T_1bf5d_row29_col0, #T_1bf5d_row29_col1, #T_1bf5d_row29_col2, #T_1bf5d_row29_col3, #T_1bf5d_row29_col4, #T_1bf5d_row29_col5, #T_1bf5d_row30_col0, #T_1bf5d_row30_col1, #T_1bf5d_row30_col2, #T_1bf5d_row30_col3, #T_1bf5d_row30_col4, #T_1bf5d_row30_col5, #T_1bf5d_row31_col0, #T_1bf5d_row31_col1, #T_1bf5d_row31_col2, #T_1bf5d_row31_col3, #T_1bf5d_row31_col4, #T_1bf5d_row31_col5, #T_1bf5d_row32_col0, #T_1bf5 ...
#   font-family: monospace;
# }
# </style>
# <table id="T_1bf5d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Value</th>
#       <th class="col_heading level0 col1" >Std Err</th>
#       <th class="col_heading level0 col2" >t Stat</th>
#       <th class="col_heading level0 col3" >Signif</th>
#       <th class="col_heading level0 col4" >Like Ratio</th>
#       <th class="col_heading level0 col5" >Null Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bf5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bf5d_row0_col0" class="data row0 col0" > 0.00</td>
#       <td id="T_1bf5d_row0_col1" class="data row0 col1" > 0.00</td>
#       <td id="T_1bf5d_row0_col2" class="data row0 col2" > NA</td>
#       <td id="T_1bf5d_row0_col3" class="data row0 col3" ></td>
#       <td id="T_1bf5d_row0_col4" class="data row0 col4" > NA</td>
#       <td id="T_1bf5d_row0_col5" class="data row0 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1bf5d_level0_row1" class="row_heading level0 row1" >coef_asc_dur_0_4_stops_0out_1in</th>
#       <td id="T_1bf5d_row1_col0" class="data row1 col0" >-0.606</td>
#       <td id="T_1bf5d_row1_col1" class="data row1 col1" > 0.508</td>
#       <td id="T_1bf5d_row1_col2" class="data row1 col2" >-1.19</td>
#       <td id="T_1bf5d_row1_col3" class="data row1 col3" ></td>
#       <td id="T_1bf5d_row1_col4" class="data row1 col4" > NA</td>
#       <td id="T_1bf5d_row1_col5" class="data row1 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1bf5d_level0_row2" class="row_heading level0 row2" >coef_asc_dur_0_4_stops_0out_2in</th>
#       <td id="T_1bf5d_row2_col0" class="data row2 col0" >-2.40</td>
#       <td id="T_1bf5d_row2_col1" class="data row2 col1" > 1.04</td>
#       <td id="T_1bf5d_row2_col2" class="data row2 col2" >-2.30</td>
#       <td id="T_1bf5d_row2_col3" class="data row2 col3" >*</td>
#       <td id="T_1bf5d_row2_col4" class="data row2 col4" > NA</td>
#       <td id="T_1bf5d_row2_col5" class="data row2 col5" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1bf5d_level0_row3" class="row_heading level0 row3" >coef_

# %% [markdown]
# # Output Estimation Results
#
# The stop frequency model include seperate coefficient file for each segment,
# and has a special writer method to seperate the coefficient by segment
# after estimation.

# %%
from activitysim.estimation.larch.stop_frequency import update_segment_coefficients
result_dir = data.edb_directory/"estimated"
update_segment_coefficients(
    model, data, result_dir,
    output_file="stop_frequency_coefficients_{segment_name}_revised.csv",
);

# %% [markdown]
# ### Write the model estimation report, including coefficient t-statistic and log likelihood

# %%
for m, segment in zip(model, data.segments):
    m.to_xlsx(
        result_dir/f"{modelname}_{segment}_model_estimation.xlsx", 
        data_statistics=True,
    )

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `stop_frequency_coefficients_*_revised.csv` files to the configs folder, rename them to `stop_frequency_coefficients_*.csv`, and run ActivitySim in simulation mode.

# %%
pd.read_csv(result_dir/"stop_frequency_coefficients_work_revised.csv")
