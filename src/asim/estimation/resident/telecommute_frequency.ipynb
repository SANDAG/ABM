# %% [markdown]
# # Estimating Telecommute Frequency Model
#
# This notebook re-estimates ActivitySim telecommute frequency model in Larch.

# %% [markdown]
# # Load libraries

# %%
import os
import larch  # !conda install larch -c conda-forge # for estimation
import pandas as pd
import numpy as np
from larch import P, X
import matplotlib.pyplot as plt
# Out:
# C:\Users\joel.freedman\AppData\Local\mambaforge\envs\asim_dev\lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# C:\Users\joel.freedman\AppData\Local\mambaforge\envs\asim_dev\lib\site-packages\sharrow\accessors.py:23: AccessorRegistrationWarning: registration of accessor <function register_dataarray_method.<locals>.wrapper at 0x0000026E79336E50> under name 'to_zarr' for type <class 'xarray.core.dataarray.DataArray'> is overriding a preexisting attribute with the same name.
#   return xr.register_dataarray_accessor(func.__name__)(wrapper)

# %% [markdown]
# The directory with the estimation data bundles for telecommute frequency.

# %%
os.chdir('/projects/SANDAG/2017 On-Call Modeling Services/Area B/TO 05 - ABM3/estimation/output/estimation_data_bundle/telecommute_frequency')

# %% [markdown]
# # Drop duplicate person records

# %%
alts_combined_data = pd.read_csv("telecommute_frequency_values_combined_orig.csv", dtype={'household_id': np.int64},low_memory=False)
#household_data = pd.read_csv("../override_households.csv",dtype={'household_id': np.int64})
#person_data = pd.read_csv("../override_persons.csv")
alts_combined_data.shape
# Out:
# (38303, 302)

# %%
#merge alts_combined data with person file
#alts_combined_per_data = pd.merge(alts_combined_data, person_data[['person_id','PNUM']], on=["person_id"], how='left')
#alts_combined_per_data.shape

# %%
#merge alts_combined data (with person file) with household file
#alts_combined_hh_data = pd.merge(alts_combined_data, household_data[['household_id','HH_ID']], on=["household_id"], how='left')
#alts_combined_hh_data.shape

# %%
#drop duplicate person records and merged columns
alts_combined_data = alts_combined_data.sort_values(by=['override_choice'])
alts_combined_new_data = alts_combined_data.drop_duplicates(subset=['HH_ID','PNUM'])
alts_combined_new_data = alts_combined_new_data[alts_combined_new_data['is_worker']==True]
#alts_combined_new_data = alts_combined_new_data.drop(columns=['household_id','PNUM','HH_ID'])
alts_combined_new_data.shape
# Out:
# (7309, 302)

# %%
#recalculate util_2016 based on survey year
alts_combined_new_data['util_2016'] = np.where(alts_combined_new_data['survey_year']==2016,1,0)
alts_combined_new_data['util_part_time'] = np.where(alts_combined_new_data['is_parttime_worker']==True,1,0)
alts_combined_new_data['util_accomodation'] = np.where(alts_combined_new_data['industry']=='accomodation',1,0)
alts_combined_new_data['util_agriculture'] = np.where(alts_combined_new_data['industry']=='agriculture',1,0)
alts_combined_new_data['util_business_srv'] = np.where(alts_combined_new_data['industry']=='business_srv',1,0)
alts_combined_new_data['util_construction'] = np.where(alts_combined_new_data['industry']=='construction',1,0)
alts_combined_new_data['util_education'] = np.where(alts_combined_new_data['industry']=='education',1,0)
alts_combined_new_data['util_entertainment'] = np.where(alts_combined_new_data['industry']=='entertainment',1,0)
alts_combined_new_data['util_food_srv'] = np.where(alts_combined_new_data['industry']=='food_srv',1,0)
alts_combined_new_data['util_government'] = np.where(alts_combined_new_data['industry']=='government',1,0)
alts_combined_new_data['util_healthcare'] = np.where(alts_combined_new_data['industry']=='healthcare',1,0)
alts_combined_new_data['util_manufacturing'] = np.where(alts_combined_new_data['industry']=='manufacturing',1,0)
alts_combined_new_data['util_mgmt_srv'] = np.where(alts_combined_new_data['industry']=='mgmt_srv',1,0)
alts_combined_new_data['util_military'] = np.where(alts_combined_new_data['industry']=='military',1,0)
alts_combined_new_data['util_retail'] = np.where(alts_combined_new_data['industry']=='retail',1,0)
alts_combined_new_data['util_asc'] = 1

# %%
#write data to file
if os.path.exists("telecommute_frequency_values_combined_orig.csv")!=True:
  shutil.copy2('telecommute_frequency_values_combined.csv','telecommute_frequency_values_combined_orig.csv')
alts_combined_new_data.to_csv("telecommute_frequency_values_combined.csv", index=False)

# %% [markdown]
# # Load data and prep model for estimation

# %%
os.chdir('/projects/SANDAG/2017 On-Call Modeling Services/Area B/TO 05 - ABM3/estimation')
modelname = "telecommute_frequency"

from activitysim.estimation.larch import component_model
model, data = component_model(modelname, return_data=True)
# Out:
# c:\development\projects\sandag_activitysim\activitysim\estimation\larch\simple_simulate.py:66: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(os.path.join(edb_directory, filename), **kwargs)

# %% [markdown]
# # Review data loaded from the EDB
#
# The next step is to read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ### Coefficients

# %%
data.coefficients
# Out:
#                              value constrain
# coefficient_name
# coef_Services_1day               0         F
# coef_SalesOffice_1day            0         F
# coef_ResourceConstruct_1day      0         F
# coef_TransportMat_1day           0         F
# coef_HasChildren0to5_1day        0         T
# ...                            ...       ...
# coef_military_4day               0         F
# coef_retail_4day                 0         F
# asc_1day                         0         F
# asc_23day                        0         F
# asc_4day                         0         F
#
# [99 rows x 2 columns]

# %% [markdown]
# #### Utility specification

# %%
data.spec
# Out:
#                     Label                     Description  \
# 0    util_HasChildren0to5   Has children 0 to 5 years old
# 1   util_HasChildren6to12  Has children 6 to 12 years old
# 2       util_OneAdultInHH                 One adult in hh
# 3             util_Female                          female
# 4     util_PartTimeWorker                Part-time worker
# 5     util_Income60to100k                  Income 60-100k
# 6    util_Income100to150k                 Income 100-150k
# 7     util_Income150kplus                    Income 150k+
# 8             util_0Autos                         0 Autos
# 9              util_1Auto                          1 Auto
# 10        util_3plusAutos                        3+ Autos
# 11    util_DistanceToWork                Distance to work
# 12        util_calib_2020           scenario year is 2020
# 13        util_calib_2025           scenario year is 2025
# 14        util_calib_2035           scenario year is 2035
# 15        util_calib_2050           scenario year is 2050
# 16              util_2016              Model year is 2016
# 17      util_accomodation           Accomodation industry
# 18       util_agriculture            Agriculture industry
# 19      util_business_srv      Business services industry
# 20      util_construction           Construction industry
# 21         util_education              Education industry
# 22     util_entertainment          Entertainment industry
# 23          util_food_srv          Food services industry
# 24        util_government             Government industry
# 25        util_healthcare             Healthcare industry
# 26     util_manufacturing          Manufacturing industry
# 27          util_mgmt_srv    Management services industry
# 28          util_military                Miliary industry
# 29            util_retail                 Retail industry
# 30               util_asc   Alternative specific constant
#
#                                        Expression  No_Telecommute  \
# 0                        @df.num_young_children>0             NaN
# 1                      @df.num_children_6_to_12>0             NaN
# 2                               @df.num_adults==1             NaN
# 3                                      @df.female             NaN
# 4                                  @df.pemploy==2             NaN
# 5               @df.income.between(60000, 100000)             NaN
# 6              @df.income.between(100000, 150000)             NaN
# 7                             @df.income > 150000             NaN
# 8                           @df.auto_ownership==0             NaN
# 9                           @df.auto_ownership==1             NaN
# 10                          @df.auto_ownership>=3             NaN
# 11                           @df.distance_to_work             NaN
# 12                            @scenarioYear==2020             NaN
# 13                            @scenarioYear==2025             NaN
# 14                            @scenarioYear==2035             NaN
# 15                            @scenarioYear==2050             NaN
# 16                                     @PRE_COVID             NaN
# 17     @np.where(df.industry=='accomodation',1,0)             NaN
# 18    @np.where(df.industry===='agriculture',1,0)             NaN
# 19   @np.where(df.industry===='business_srv',1,0)             NaN
# 20   @np.where(df.industry===='construction',1,0)             NaN
# 21      @np.where(df.industry===='education',1,0)             NaN
# 22  @np.where(df.industry===='entertainment',1,0)             NaN
# 23       @np.where(df.industry===='food_srv',1,0)             NaN
# 24     @np.where(df.industry===='government',1,0)             NaN
# 25     @np.where(df.industry===='healthcare',1,0)             NaN
# 26  @np.where(df.industry===='manufacturing',1,0)             NaN
# 27       @np.where(df.industry===='mgmt_srv',1,0)             NaN
# 28       @np.where(df.industry===='military',1,0)             NaN
# 29         @np.where(df.industry===='retail',1,0)             NaN
# 30                                              1             NaN
#
#                      1_day_week                2_3_days_week  \
# 0     coef_HasChildren0to5_1day  coef_HasChildren0to5_234day
# 1    coef_HasChildren6to12_1day  coef_HasChildren6to12_23day
# 2        coef_OneAdultInHH_1day      coef_OneAdultInHH_23day
# 3           coef_Female_1234day          coef_Female_1234day
# 4   coef_PartTimeWorker_1234day  coef_PartTimeWorker_1234day
# 5      coef_Income60to100k_1day    coef_Income60to100k_23day
# 6     coef_Income100to150k_1day  coef_Income100to150k_234day
# 7      coef_Income150kplus_1day    coef_Income150kplus_23day
# 8              coef_0Autos_1day           coef_0Autos_234day
# 9               coef_1Auto_1day            coef_1Auto_234day
# 10         coef_3plusAutos_1day        coef_3plusAutos_23day
# 11     coef_DistanceToWork_1day   coef_DistanceToWork_234day
# 12         coef_calib_2020_1day        coef_calib_2020_23day
# 13         coef_calib_2025_1day        coef_calib_2025_23day
# 14         coef_calib_2035_1day        coef_calib_2035_23day
# 15         coef_calib_2050_1day        coef_calib_2050_23day
# 16               coef_2016_1day              coef_2016_23day
# 17    coef_accomodation_1234day    coef_accomodation_1234day
# 18     coef_agriculture_1234day     coef_agriculture_1234day
# 19       coef_business_srv_1day      coef_business_srv_23day
# 20       coef_construction_1day     coef_construction_234day
# 21       coef_education_1234day       coef_education_1234day
# 22      coef_entertainment_1day     coef_entertainment_23day
# 23        coef_food_srv_1234day        coef_food_srv_1234day
# 24         coef_government_1day       coef_government_234day
# 25      coef_healthcare_1234day      coef_healthcare_1234day
# 26      coef_manufacturing_1day    coef_manufacturing_234day
# 27           coef_mgmt_srv_1day          coef_mgmt_srv_23day
# 28           coef_military_1day         coef_military_234day
# 29             coef_retail_1day            coef_retail_23day
# 30                     asc_1day                    asc_23day
#
#                     4_days_week
# 0   coef_HasChildren0to5_234day
# 1    coef_HasChildren6to12_4day
# 2        coef_OneAdultInHH_4day
# 3           coef_Female_1234day
# 4   coef_PartTimeWorker_1234day
# 5      coef_Income60to100k_4day
# 6   coef_Income100to150k_234day
# 7      coef_Income150kplus_4day
# 8            coef_0Autos_234day
# 9             coef_1Auto_234day
# 10         coef_3plusAutos_4day
# 11   coef_DistanceToWork_234day
# 12         coef_calib_2020_4day
# 13         coef_calib_2025_4day
# 14         coef_calib_2035_4day
# 15         coef_calib_2050_4day
# 16               coef_2016_4day
# 17    coef_accomodation_1234day
# 18     coef_agriculture_1234day
# 19       coef_business_srv_4day
# 20     coef_construction_234day
# 21       coef_education_1234day
# 22      coef_entertainment_4day
# 23        coef_food_srv_1234day
# 24       coef_government_234day
# 25      coef_healthcare_1234day
# 26    coef_manufacturing_234day
# 27           coef_mgmt_srv_4day
# 28         coef_military_234day
# 29             coef_retail_4day
# 30                     asc_4day

# %% [markdown]
# ## Explore data

# %% [raw]
# data.chooser_data

# %%
data.chooser_data
# Out:
#               person_id   model_choice override_choice  util_HasChildren0to5  \
# household_id
# 33961             67009     1_day_week      1_day_week                   0.0
# 29671             58590    4_days_week      1_day_week                   0.0
# 42929             84716  2_3_days_week      1_day_week                   0.0
# 29668             58582  2_3_days_week      1_day_week                   1.0
# 7075              13954  2_3_days_week      1_day_week                   1.0
# ...                 ...            ...             ...                   ...
# 16963             33499     1_day_week  No_Telecommute                   0.0
# 16468             32476  2_3_days_week  No_Telecommute                   0.0
# 17900             35345    4_days_week  No_Telecommute                   0.0
# 17472             34494  2_3_days_week  No_Telecommute                   1.0
# 49762             96881     1_day_week  No_Telecommute                   0.0
#
#               util_HasChildren6to12  util_OneAdultInHH  util_2plusAdultsInHH  \
# household_id
# 33961                           0.0                0.0                   1.0
# 29671                           0.0                0.0                   1.0
# 42929                           0.0                1.0                   0.0
# 29668                           0.0                0.0                   1.0
# 7075                            0.0                0.0                   1.0
# ...                             ...                ...                   ...
# 16963                           0.0                1.0                   0.0
# 16468                           0.0                1.0                   0.0
# 17900                           1.0                0.0                   1.0
# 17472                           1.0                0.0                   1.0
# 49762                           0.0                1.0                   0.0
#
#               util_Female  util_PartTimeWorker  util_CollegeStudent  ...  \
# household_id                                                         ...
# 33961                 0.0                  0.0                  0.0  ...
# 29671                 1.0                  0.0                  0.0  ...
# 42929                 0.0                  1.0                  0.0  ...
# 29668                 0.0                  0.0                  0.0  ...
# 7075                  0.0                  0.0                  0.0  ...
# ...                   ...                  ...                  ...  ...
# 16963                 1.0                  0.0                  0.0  ...
# 16468                 0.0                  0.0                  0.0  ...
# 17900                 1.0                  1.0                  0.0  ...
# 17472                 0.0                  0.0                  0.0  ...
# 49762                 1.0                  0.0                  0.0  ...
#
#               util_entertainment  util_food_srv  util_government  \
# household_id
# 33961                          0              0                0
# 29671                          0              0                0
# 42929                          0              0                0
# 29668                          0              0                0
# 7075                           0              0                0
# ...                          ...            ...              ...
# 16963                          0              0                0
# 16468                          0              0                0
# 17900                          0              0                0
# 17472                          0              0                0
# 49762                          0              0                0
#
#               util_healthcare  util_manufacturing  util_mgmt_srv  \
# household_id
# 33961                       0                   0              0
# 29671                       1                   0              0
# 42929                       0                   0              0
# 29668                       0                   0              0
# 7075                        0                   0              0
# ...                       ...                 ...            ...
# 16963                       1                   0              0
# 16468                       1                   0              0
# 17900                       0                   0              0
# 17472                       1                   0              0
# 49762                       0                   0              0
#
#               util_military  util_retail  util_asc  override_choice_code
# household_id
# 33961                     0            0         1                     2
# 29671                     0            0         1                     2
# 42929                     0            0         1                     2
# 29668                     0            0         1                     2
# 7075                      0            0         1                     2
# ...                     ...          ...       ...                   ...
# 16963                     0            0         1                     1
# 16468                     0            0         1                     1
# 17900                     0            0         1                     1
# 17472                     0            0         1                     1
# 49762                     0            0         1                     1
#
# [7309 rows x 318 columns]

# %%
pd.crosstab(data.chooser_data.override_choice, data.chooser_data.survey_year, margins=True)
# Out:
# survey_year      2016  2022   All
# override_choice
# 1_day_week        737   224   961
# 2_3_days_week     283   210   493
# 4_days_week        35   312   347
# No_Telecommute   4317  1191  5508
# All              5372  1937  7309

# %% [markdown]
# # Set Coefficients

# %%
dir(model)
print(model.utility_co)
# Out:
# DictOfLinearFunction_C({1: <Empty LinearFunction_C>, 2:   P.coef_HasChildren0to5_1day * X.util_HasChildren0to5
# + P.coef_HasChildren6to12_1day * X.util_HasChildren6to12
# + P.coef_OneAdultInHH_1day * X.util_OneAdultInHH
# + P.coef_Female_1234day * X.util_Female
# + P.coef_PartTimeWorker_1234day * X.util_PartTimeWorker
# + P.coef_Income60to100k_1day * X.util_Income60to100k
# + P.coef_Income100to150k_1day * X.util_Income100to150k
# + P.coef_Income150kplus_1day * X.util_Income150kplus
# + P.coef_0Autos_1day * X.util_0Autos
# + P.coef_1Auto_1day * X.util_1Auto
# + P.coef_3plusAutos_1day * X.util_3plusAutos
# + P.coef_DistanceToWork_1day * X.util_DistanceToWork
# + P.coef_calib_2020_1day * X.util_calib_2020
# + P.coef_calib_2025_1day * X.util_calib_2025
# + P.coef_calib_2035_1day * X.util_calib_2035
# + P.coef_calib_2050_1day * X.util_calib_2050
# + P.coef_2016_1day * X.util_2016
# + P.coef_accomodation_1234day * X.util_accomodation
# + P.coef_agriculture_1234day * X.util_agriculture
# + P.coef_business_srv_1day * X.util_business_srv
# + P.coef_construction_1day * X.util_construction
# + P.coef_education_1234day * X.util_education
# + P.coef_entertainment_1day * X.util_entertainment
# + P.coef_food_srv_1234day * X.util_food_srv
# + P.coef_government_1day * X.util_government
# + P.coef_healthcare_1234day * X.util_healthcare
# + P.coef_manufacturing_1day * X.util_manufacturing
# + P.coef_mgmt_srv_1day * X.util_mgmt_srv
# + P.coef_military_1day * X.util_military
# + P.coef_retail_1day * X.util_retail
# + P.asc_1day * X.util_asc, 3:   P.coef_HasChildren0to5_234day * X.util_HasChildren0to5
# + P.coef_HasChildren6to12_23day * X.util_HasChildren6to12
# + P.coef_OneAdultInHH_23day * X.util_OneAdultInHH
# + P.coef_Female_1234day * X.util_Female
# + P.coef_PartTimeWorker_1234day * X.util_PartTimeWorker
# + P.coef_Income60to100k_23day * X.util_Income60to100k
# + P.coef_Income100to150k_234day * X.util_Income100to150k
# + P.coef_Income150kplus_23day * X.util_Income150kplus
# + P.coef_0Autos_234day * X.util_0Autos
# + P.coef_1Auto_234day * X.util_1Auto
# + P.coef_3plusAutos_23day * X.util_3plusAutos
# + P.coef_DistanceToWork_234day * X.util_DistanceToWork
# + P.coef_calib_2020_23day * X.util_calib_2020
# + P.coef_calib_2025_23day * X.util_calib_2025
# + P.coef_calib_2035_23day * X.util_calib_2035
# + P.coef_calib_2050_23day * X.util_calib_2050
# + P.coef_2016_23day * X.util_2016
# + P.coef_accomodation_1234day * X.util_accomodation
# + P.coef_agriculture_1234day * X.util_agriculture
# + P.coef_business_srv_23day * X.util_business_srv
# + P.coef_construction_234day * X.util_construction
# + P.coef_education_1234day * X.util_education
# + P.coef_entertainment_23day * X.util_entertainment
# + P.coef_food_srv_1234day * X.util_food_srv
# + P.coef_government_234day * X.util_government
# + P.coef_healthcare_1234day * X.util_healthcare
# + P.coef_manufacturing_234day * X.util_manufacturing
# + P.coef_mgmt_srv_23day * X.util_mgmt_srv
# + P.coef_military_234day * X.util_military
# + P.coef_retail_23day * X.util_retail
# + P.asc_23day * X.util_asc, 4:   P.coef_HasChildren0to5_234day * X.util_HasChildren0to5
# + P.coef_HasChildren6to12_4day * X.util_HasChildren6to12
# + P.coef_OneAdultInHH_4day * X.util_OneAdultInHH
# + P.coef_Female_1234day * X.util_Female
# + P.coef_PartTimeWorker_1234day * X.util_PartTimeWorker
# + P.coef_Income60to100k_4day * X.util_Income60to100k
# + P.coef_Income100to150k_234day * X.util_Income100to150k
# + P.coef_Income150kplus_4day * X.util_Income150kplus
# + P.coef_0Autos_234day * X.util_0Autos
# + P.coef_1Auto_234day * X.util_1Auto
# + P.coef_3plusAutos_4day * X.util_3plusAutos
# + P.coef_DistanceToWork_234day * X.util_DistanceToWork
# + P.coef_calib_2020_4day * X.util_calib_2020
# + P.coef_calib_2025_4day * X.util_calib_2025
# + P.coef_calib_2035_4day * X.util_calib_2035
# + P.coef_calib_2050_4day * X.util_calib_2050
# + P.coef_2016_4day * X.util_2016
# + P.coef_accomodation_1234day * X.util_accomodation
# + P.coef_agriculture_1234day * X.util_agriculture
# + P.coef_business_srv_4day * X.util_business_srv
# + P.coef_construction_234day * X.util_construction
# + P.coef_education_1234day * X.util_education
# + P.coef_entertainment_4day * X.util_entertainment
# + P.coef_food_srv_1234day * X.util_food_srv
# + P.coef_government_234day * X.util_government
# + P.coef_healthcare_1234day * X.util_healthcare
# + P.coef_manufacturing_234day * X.util_manufacturing
# + P.coef_mgmt_srv_4day * X.util_mgmt_srv
# + P.coef_military_234day * X.util_military
# + P.coef_retail_4day * X.util_retail
# + P.asc_4day * X.util_asc})

# %%
#model.utility_co = {0: P.coef_dist_to_nearest_ext_station * X.util_dist_to_nearest_ext_station
#+ P.coef_size_of_nearest_ext_station * X.util_size_of_nearest_ext_station
#+ P.coef_part_time * X.parttime
#+ P.coef_agriculture * X.agriculture
#+ P.coef_business_srv * X.business_srv
#+ P.coef_construction * X.construction
#+ P.coef_education * X.education
#+ P.coef_entertainment * X.entertainment
#+ P.coef_food_srv * X.food_srv                   
#+ P.coef_government * X.government
#+ P.coef_healthcare * X.healthcare                   
#+ P.coef_manufacturing * X.manufacturing
#+ P.coef_mgmt_srv * X.mgmt_srv
#+ P.coef_military * X.military
#+ P.coef_retail * X.retail    
#+ P.coef_inc_lt15 * X("income<15000")
#+ P.coef_inc_15_25 * X("(income>=15000) * (income<25000)") 
#+ P.coef_inc_25_50 * X("(income>=25000) * (income<50000)") 
#+ P.coef_inc_100_150 * X.income_100_150 
#+ P.coef_inc_150_250 * X("(income>=150000) * (income<250000)")  
#+ P.coef_inc_250plus * X("income>=250000")
#+ P.asc_external_2016 * X.year_2016         
#+ P.coef_dist_lt_2p5 * X("util_dist_to_nearest_ext_station<2.5")                    
#+ P.asc_external_worker * X.util_asc_placeholder, 1: 0}

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.load_data()
#model.doctor(repair_ch_av="-")
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>

# %%
model.maximize_loglike(method="SLSQP", options={"maxiter": 1000})
# Out:
# <h3>Iteration 041 [Optimization terminated successfully] </h3>
# <p>Best LL = -5283.181318490329</p>
#                          value  initvalue  nullvalue  minimum  maximum  \
# asc_1day             -1.821844        0.0        0.0      NaN      NaN
# asc_23day            -1.768458        0.0        0.0      NaN      NaN
# asc_4day             -1.372632        0.0        0.0      NaN      NaN
# coef_0Autos_1day      0.000000        0.0        0.0      0.0      0.0
# coef_0Autos_234day    0.000000        0.0        0.0      0.0      0.0
# ...                        ...        ...        ...      ...      ...
# coef_military_1day    0.000000        0.0        0.0      0.0      0.0
# coef_military_234day -0.512647        0.0        0.0      NaN      NaN
# coef_retail_1day     -0.832034        0.0        0.0      NaN      NaN
# coef_retail_23day    -0.757629        0.0        0.0      NaN      NaN
# coef_retail_4day     -2.233899        0.0        0.0      NaN      NaN
#
#                       holdfast note      best
# asc_1day                     0      -1.821844
# asc_23day                    0      -1.768458
# asc_4day                     0      -1.372632
# coef_0Autos_1day             1       0.000000
# coef_0Autos_234day           1       0.000000
# ...                        ...  ...       ...
# coef_military_1day           1       0.000000
# coef_military_234day         0      -0.512647
# coef_retail_1day             0      -0.832034
# coef_retail_23day            0      -0.757629
# coef_retail_4day             0      -2.233899
#
# [70 rows x 8 columns]
# ┣                x: asc_1day               -1.821844
# ┃                   asc_23day              -1.768458
# ┃                   asc_4day               -1.372632
# ┃                   coef_0Autos_1day        0.000000
# ┃                   coef_0Autos_234day      0.000000
# ┃                                             ...
# ┃                   coef_military_1day      0.000000
# ┃                   coef_military_234day   -0.512647
# ┃                   coef_retail_1day       -0.832034
# ┃                   coef_retail_23day      -0.757629
# ┃                   coef_retail_4day       -2.233899
# ┃                   Length: 70, dtype: float64
# ┣          loglike: -5283.181318490329
# ┣        d_loglike: asc_1day                0.017476
# ┃                   asc_23day              -0.006657
# ┃                   asc_4day               -0.004857
# ┃                   coef_0Autos_1day        0.000000
# ┃                   coef_0Autos_234day      0.000000
# ┃                                             ...
# ┃                   coef_military_1day      0.000000
# ┃                   coef_military_234day   -0.000913
# ┃                   coef_retail_1day        0.000834
# ┃                   coef_retail_23day      -0.000452
# ┃                   coef_retail_4day       -0.000621
# ┃                   Length: 70, dtype: float64
# ┣              nit: 41
# ┣             nfev: 110
# ┣             njev: 41
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=12, microseconds=588110)
# ┣           method: 'SLSQP'
# ┣          n_cases: 7309
# ┣ iteration_number: 41
# ┣          logloss: 0.722832305170383

# %% [markdown]
# ### Estimated coefficients

# %%
model.calculate_parameter_covariance()
result_dir='/projects/SANDAG/2017 On-Call Modeling Services/Area B/TO 05 - ABM3/estimation/'
model.to_xlsx(
        result_dir+"telecommute_frequency_004.xlsx", 
        data_statistics=True,
    )
# Out:
# C:\Users\joel.freedman\AppData\Local\mambaforge\envs\asim_dev\lib\site-packages\larch\util\excel.py:523: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.
#   xl = ExcelWriter(filename, engine='xlsxwriter_larch', model=model, **kwargs)

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients
result_dir = data.edb_directory/"estimated"
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_004.csv",
);

# %%
#larch.__version__

# %%
#result_dir

# %% [markdown]
# ### Write the model estimation report, including coefficient t-statistic and log likelihood

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file to the configs folder, rename it to `*_coefficients.csv`, and run ActivitySim in simulation mode.

# %%
#pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
