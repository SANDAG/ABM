# %% [markdown]
# # Estimating Auto Ownership Model
#
# This notebook re-estimates ActivitySim auto ownership model in Larch.

# %% [markdown]
# # Load libraries

# %%
import os
import larch  # !conda install larch -c conda-forge # for estimation
import pandas as pd
import numpy as np
from larch import P, X
import matplotlib.pyplot as plt

# %% [markdown]
# The directory with the estimation data bundles for auto ownership (in output/estimation_data_bundle).

# %%
os.chdir('/projects/SANDAG/2017 On-Call Modeling Services/Area B/TO 05 - ABM3/estimation')

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname = "auto_ownership"

from activitysim.estimation.larch import component_model
model, data = component_model(modelname, return_data=True)

# %% [markdown]
# # Review data loaded from the EDB
#
# The next step is to read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ### Coefficients

# %%
data.coefficients
# Out:
#                                                     value constrain
# coefficient_name
# coef_alternative_specific_constant_for_1_driver...      0         F
# coef_alternative_specific_constant_for_1_driver...      0         F
# coef_alternative_specific_constant_for_1_driver...      0         F
# coef_alternative_specific_constant_for_1_driver...      0         F
# coef_alternative_specific_constant_for_2_driver...      0         F
# ...                                                   ...       ...
# coef_NEST_0_1CARS                                       1         T
# cars0_2016                                              0         F
# cars2_2016                                              0         F
# cars3_2016                                              0         F
# cars4_2016                                              0         F
#
# [102 rows x 2 columns]

# %% [markdown]
# #### Utility specification

# %%
data.spec
# Out:
#                                    Label  \
# 0                         util_drivers_1
# 1                         util_drivers_2
# 2                         util_drivers_3
# 3                        util_drivers_4p
# 4                         util_has_18_24
# 5                         util_has_25_34
# 6                         util_has_65_79
# 7                        util_has_80plus
# 8                           util_has_0_4
# 9                          util_has_5_17
# 10                     util_has_1_worker
# 11                    util_has_2_workers
# 12                util_has_3plus_workers
# 13                util_hh_income_verylow
# 14                    util_hh_income_low
# 15                    util_hh_income_mid
# 16               util_hh_income_veryhigh
# 17                         util_attached
# 18             util_intersection_density
# 19                      util_pop_density
# 20                   util_retail_density
# 21                 util_nm_accessibility
# 22  util_auto_minus_transit_accessiblity
# 23             util_nonmand_logsum_0auto
# 24             util_nonmand_logsum_1auto
# 25            util_nonmand_logsum_2pauto
# 26                              util_asc
# 27                           util_asc_gq
# 28                             util_2016
#
#                                           Description  \
# 0   alternative specific constant for 1 driver hou...
# 1   alternative specific constant for 2 driver hou...
# 2   alternative specific constant for 3 driver hou...
# 3   alternative specific constant for 4+ driver ho...
# 4                       Presence of persons age 18-24
# 5                       Presence of persons age 35-34
# 6                       Presence of persons age 65-79
# 7                         Presence of persons age 80+
# 8                        Presence of children age 0-4
# 9                       Presence of children age 5-17
# 10                                     Has one worker
# 11                                    Has two workers
# 12                          Has three or more workers
# 13                              household income <15k
# 14                           household income 15k-30k
# 15                            household income 30-60k
# 16                             household income 100k+
# 17                                  attached dwelling
# 18  Intersection count in 1/2 mile radius of house...
# 19  Population Density in 1/2 mile radius of house...
# 20  Retail Employment Density in 1/2 mile radius o...
# 21                   Non-motorized zonal accessbility
# 22                   auto-transit zonal accessibility
# 23  Average non-mandatory disaggrage accessibility...
# 24  Average non-mandatory disaggrage accessibility...
# 25  Average non-mandatory disaggrage accessibility...
# 26  alternative specific constant adjustment for a...
# 27  alternative specific constant adjustment for G...
# 28                                 Model year is 2016
#
#                                            Expression  \
# 0                                  @df.num_drivers==1
# 1                                  @df.num_drivers==2
# 2                                  @df.num_drivers==3
# 3                                  @df.num_drivers>=4
# 4                               (num_college_age > 0)
# 5                              (num_young_adults > 0)
# 6                              num_young_retirees > 0
# 7                                num_old_retirees > 0
# 8                              (num_young_children>0)
# 9      (num_children_5_to_15+num_children_16_to_17)>0
# 10                                 @df.num_workers==1
# 11                                 @df.num_workers==2
# 12                                  @df.num_workers>2
# 13                                 @(df.income<15000)
# 14          @((df.income>=15000) & (df.income<30000))
# 15          @((df.income>=30000) & (df.income<60000))
# 16                               @(df.income>=100000)
# 17                        @(where(df.bldgsz == 2,0,1)
# 18                                         totint/502
# 19                                             popden
# 20                                             empden
# 21                                           nmRetail
# 22                              auPkTotal - trPkTotal
# 23  (shopping_accessibility_0 + othdiscr_accessibi...
# 24  (shopping_accessibility_1 + othdiscr_accessibi...
# 25  (shopping_accessibility_2 + othdiscr_accessibi...
# 26                                                  1
# 27                                       @(df.HHT==0)
# 28                      np.where(model_year=2016,1,0)
#
#                                                 cars0  \
# 0   coef_alternative_specific_constant_for_1_drive...
# 1   coef_alternative_specific_constant_for_2_drive...
# 2   coef_alternative_specific_constant_for_3_drive...
# 3   coef_alternative_specific_constant_for_4_drive...
# 4                                coef_cars0_has_18_24
# 5                                coef_cars0_has_25_34
# 6                                coef_cars0_has_65_79
# 7                               coef_cars0_has_80plus
# 8                                  coef_cars0_has_0_4
# 9                                 coef_cars0_has_5_17
# 10                               coef_cars0_workers_1
# 11                               coef_cars0_workers_2
# 12                           coef_cars0_workers_3plus
# 13                   coef_household_income_15k_0_CARS
# 14                 coef_household_income_1530k_0_CARS
# 15                 coef_household_income_3060k_0_CARS
# 16                  coef_household_income_100k_0_CARS
# 17                               coef_attached_0_CARS
# 18                   coef_intersection_density_0_CARS
# 19                     coef_population_density_0_CARS
# 20                         coef_retail_density_0_CARS
# 21        coef_nonmotorized_zonal_accessbility_0_CARS
# 22        coef_autotransit_zonal_accessibility_0_CARS
# 23                              coef_nonmand_logsum_0
# 24                                                NaN
# 25                                                NaN
# 26                                 asc_allhhs_0_autos
# 27                                     asc_GQ_0_autos
# 28                                         cars0_2016
#
#                                                 cars1  \
# 0                                                 NaN
# 1   coef_alternative_specific_constant_for_2_drive...
# 2   coef_alternative_specific_constant_for_3_drive...
# 3   coef_alternative_specific_constant_for_4_drive...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                              coef_nonmand_logsum_1
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
#
#                                                 cars2  \
# 0   coef_alternative_specific_constant_for_1_drive...
# 1                                                 NaN
# 2   coef_alternative_specific_constant_for_3_drive...
# 3   coef_alternative_specific_constant_for_4_drive...
# 4                                coef_cars2_has_18_24
# 5                                coef_cars2_has_25_34
# 6                                coef_cars2_has_65_79
# 7                               coef_cars2_has_80plus
# 8                                  coef_cars2_has_0_4
# 9                                 coef_cars2_has_5_17
# 10                               coef_cars2_workers_1
# 11                               coef_cars2_workers_2
# 12                           coef_cars2_workers_3plus
# 13                   coef_household_income_15k_2_CARS
# 14                 coef_household_income_1530k_2_CARS
# 15                 coef_household_income_3060k_2_CARS
# 16                  coef_household_income_100k_2_CARS
# 17                               coef_attached_2_CARS
# 18                   coef_intersection_density_2_CARS
# 19                     coef_population_density_2_CARS
# 20                         coef_retail_density_2_CARS
# 21        coef_nonmotorized_zonal_accessbility_2_CARS
# 22        coef_autotransit_zonal_accessibility_2_CARS
# 23                                                NaN
# 24                                                NaN
# 25                             coef_nonmand_logsum_2p
# 26                                 asc_allhhs_2_autos
# 27                                   coef_unavailable
# 28                                         cars2_2016
#
#                                                 cars3  \
# 0   coef_alternative_specific_constant_for_1_drive...
# 1   coef_alternative_specific_constant_for_2_drive...
# 2                                                 NaN
# 3   coef_alternative_specific_constant_for_4_drive...
# 4                               coef_cars34_has_18_24
# 5                               coef_cars34_has_25_34
# 6                               coef_cars34_has_65_79
# 7                              coef_cars34_has_80plus
# 8                                 coef_cars34_has_0_4
# 9                                coef_cars34_has_5_17
# 10                              coef_cars34_workers_1
# 11                              coef_cars34_workers_2
# 12                          coef_cars34_workers_3plus
# 13                   coef_household_income_15k_3_CARS
# 14                 coef_household_income_1530k_3_CARS
# 15                 coef_household_income_3060k_3_CARS
# 16                  coef_household_income_100k_3_CARS
# 17                               coef_attached_3_CARS
# 18                   coef_intersection_density_3_CARS
# 19                    coef_population_density_34_CARS
# 20                         coef_retail_density_3_CARS
# 21        coef_nonmotorized_zonal_accessbility_3_CARS
# 22        coef_autotransit_zonal_accessibility_3_CARS
# 23                                                NaN
# 24                                                NaN
# 25                             coef_nonmand_logsum_2p
# 26                                  asc_allhs_3_autos
# 27                                   coef_unavailable
# 28                                         cars3_2016
#
#                                                 cars4            Unnamed: 8
# 0   coef_alternative_specific_constant_for_1_drive...                   NaN
# 1   coef_alternative_specific_constant_for_2_drive...                   NaN
# 2   coef_alternative_specific_constant_for_3_drive...                   NaN
# 3                                                 NaN                   NaN
# 4                               coef_cars34_has_18_24                   NaN
# 5                               coef_cars34_has_25_34                   NaN
# 6                               coef_cars34_has_65_79                   NaN
# 7                              coef_cars34_has_80plus                   NaN
# 8                                 coef_cars34_has_0_4                   NaN
# 9                                coef_cars34_has_5_17                   NaN
# 10                              coef_cars34_workers_1  coef_cars0_workers_6
# 11                              coef_cars34_workers_1                   NaN
# 12                          coef_cars34_workers_3plus                   NaN
# 13                   coef_household_income_15k_4_CARS                   NaN
# 14                 coef_household_income_1530k_4_CARS                   NaN
# 15                 coef_household_income_3060k_4_CARS                   NaN
# 16                  coef_household_income_100k_4_CARS                   NaN
# 17                               coef_attached_4_CARS                   NaN
# 18                   coef_intersection_density_4_CARS                   NaN
# 19                    coef_population_density_34_CARS                   NaN
# 20                         coef_retail_density_4_CARS                   NaN
# 21        coef_nonmotorized_zonal_accessbility_4_CARS                   NaN
# 22        coef_autotransit_zonal_accessibility_4_CARS                   NaN
# 23                                                NaN                   NaN
# 24                                                NaN                   NaN
# 25                             coef_nonmand_logsum_2p                   NaN
# 26                             asc_allhhs_4plus_autos                   NaN
# 27                                   coef_unavailable                   NaN
# 28                                         cars4_2016                   NaN

# %% [markdown]
# ## Explore data

# %%
data.chooser_data
# Out:
#               model_choice  override_choice  util_drivers_1  util_drivers_2  \
# household_id
# 1                        3                2               0               1
# 2                        0                2               0               1
# 3                        0                1               1               0
# 4                        0                3               0               1
# 5                        3                1               0               1
# ...                    ...              ...             ...             ...
# 44589                    1                1               1               0
# 48063                    1                1               0               1
# 48064                    1                1               1               0
# 49762                    2                1               1               0
# 46284                    0                0               1               0
#
#               util_drivers_3  util_drivers_4p  util_persons_16_17  \
# household_id
# 1                          0                0                   0
# 2                          0                0                   0
# 3                          0                0                   0
# 4                          0                0                   0
# 5                          0                0                   0
# ...                      ...              ...                 ...
# 44589                      0                0                   0
# 48063                      0                0                   0
# 48064                      0                0                   0
# 49762                      0                0                   0
# 46284                      0                0                   0
#
#               util_persons_18_24  util_persons_25_34  util_has_18_24  ...  \
# household_id                                                          ...
# 1                              0                   0               0  ...
# 2                              0                   0               0  ...
# 3                              1                   0               1  ...
# 4                              0                   0               0  ...
# 5                              0                   0               0  ...
# ...                          ...                 ...             ...  ...
# 44589                          0                   1               0  ...
# 48063                          0                   0               0  ...
# 48064                          1                   0               1  ...
# 49762                          0                   0               0  ...
# 46284                          1                   0               1  ...
#
#               preschool_target  is_parking_zone  shopping_accessibility_0  \
# household_id
# 1                          315             True                 11.538816
# 2                          156             True                 11.807039
# 3                          240             True                 12.744699
# 4                          239             True                 12.973414
# 5                           97             True                 11.958179
# ...                        ...              ...                       ...
# 44589                      286             True                 14.403127
# 48063                        0             True                 11.943152
# 48064                     1028             True                 12.337126
# 49762                      858             True                 11.526566
# 46284                        0             True                 11.696687
#
#               shopping_accessibility_1  shopping_accessibility_2  \
# household_id
# 1                            11.086219                 11.217657
# 2                            11.389310                 11.339877
# 3                            12.191229                 12.060988
# 4                            12.131250                 11.800279
# 5                            11.186803                 11.269519
# ...                                ...                       ...
# 44589                        13.669578                 13.162124
# 48063                        11.871376                 10.778622
# 48064                        11.879260                 11.438389
# 49762                        10.899991                 10.909738
# 46284                        10.886163                 10.297296
#
#               othdiscr_accessibility_0  othdiscr_accessibility_1  \
# household_id
# 1                            15.552833                 15.204355
# 2                            14.357026                 13.978252
# 3                            14.775725                 14.323247
# 4                            16.350536                 15.744719
# 5                            14.740860                 14.043881
# ...                                ...                       ...
# 44589                        17.174279                 16.511511
# 48063                        15.158994                 14.774424
# 48064                        15.100142                 14.147283
# 49762                        14.080078                 13.737474
# 46284                        18.260582                 18.083619
#
#               othdiscr_accessibility_2  res_type  override_choice_code
# household_id
# 1                            14.884606         1                     3
# 2                            13.464349         1                     3
# 3                            13.877434         4                     2
# 4                            15.663887         1                     4
# 5                            13.959714         1                     2
# ...                                ...       ...                   ...
# 44589                        15.836580         3                     2
# 48063                        14.634361         6                     2
# 48064                        13.978258         4                     2
# 49762                        13.444756         1                     2
# 46284                        17.737319         6                     1
#
# [8980 rows x 223 columns]

# %%
pd.crosstab(data.chooser_data.HHT, data.chooser_data.override_choice, margins=True)
# Out:
# override_choice    0     1     2    3    4   All
# HHT
# 0                 20     8     1    0    0    29
# 1                 42   331   847  237   77  1534
# 4                660  3450  2365  658  284  7417
# All              722  3789  3213  895  361  8980

# %%
pd.crosstab(data.chooser_data.num_workers, data.chooser_data.override_choice, margins=True)
# Out:
# override_choice    0     1     2    3    4   All
# num_workers
# 0                459  1478   730  170   53  2890
# 1                234  2042  1073  296  110  3755
# 2                 19   259  1383  371  144  2176
# 3                  2     9    26   54   35   126
# 4                  0     1     0    3   12    16
# 5                  8     0     1    1    4    14
# 6                  0     0     0    0    1     1
# 7                  0     0     0    0    2     2
# All              722  3789  3213  895  361  8980

# %%
#plt.hist(data.chooser_data['distance_int'],range=(0, data.chooser_data['distance_int'].max()), bins=data.chooser_data['distance_int'].max() + 1)
#plot_df = data.chooser_data.groupby('distance_int')['external_worker'].mean().mul(100).reindex(range(data.chooser_data.distance_int.min()-1,data.chooser_data.distance_int.max()+1), fill_value=0)

#ax = plot_df.plot(kind='bar',rot = 0,title='Share of External Workers by Distance to Closest External Station',ylim=[0, 30], xlabel="Distance (mi)", ylabel="Percent",  figsize=(20, 5))

#plt.show()

# %% [markdown]
# # Set Coefficients

# %%
dir(model)
print(model.utility_co)
# Out:
# DictOfLinearFunction_C({1:   P.coef_alternative_specific_constant_for_1_driver_household_0_CARS * X.util_drivers_1
# + P.coef_alternative_specific_constant_for_2_driver_household_0_CARS * X.util_drivers_2
# + P.coef_alternative_specific_constant_for_3_driver_household_0_CARS * X.util_drivers_3
# + P.coef_alternative_specific_constant_for_4_driver_household_0_CARS * X.util_drivers_4p
# + P.coef_cars0_has_18_24 * X.util_has_18_24
# + P.coef_cars0_has_25_34 * X.util_has_25_34
# + P.coef_cars0_has_65_79 * X.util_has_65_79
# + P.coef_cars0_has_80plus * X.util_has_80plus
# + P.coef_cars0_has_0_4 * X.util_has_0_4
# + P.coef_cars0_has_5_17 * X.util_has_5_17
# + P.coef_cars0_workers_1 * X.util_has_1_worker
# + P.coef_cars0_workers_2 * X.util_has_2_workers
# + P.coef_cars0_workers_3plus * X.util_has_3plus_workers
# + P.coef_household_income_15k_0_CARS * X.util_hh_income_verylow
# + P.coef_household_income_1530k_0_CARS * X.util_hh_income_low
# + P.coef_household_income_3060k_0_CARS * X.util_hh_income_mid
# + P.coef_household_income_100k_0_CARS * X.util_hh_income_veryhigh
# + P.coef_attached_0_CARS * X.util_attached
# + P.coef_intersection_density_0_CARS * X.util_intersection_density
# + P.coef_population_density_0_CARS * X.util_pop_density
# + P.coef_retail_density_0_CARS * X.util_retail_density
# + P.coef_nonmotorized_zonal_accessbility_0_CARS * X.util_nm_accessibility
# + P.coef_autotransit_zonal_accessibility_0_CARS * X.util_auto_minus_transit_accessiblity
# + P.coef_nonmand_logsum_0 * X.util_nonmand_logsum_0auto
# + P.asc_allhhs_0_autos * X.util_asc
# + P.asc_GQ_0_autos * X.util_asc_gq
# + P.cars0_2016 * X.util_2016, 2:   P.coef_alternative_specific_constant_for_2_driver_household_1_CAR * X.util_drivers_2
# + P.coef_alternative_specific_constant_for_3_driver_household_1_CAR * X.util_drivers_3
# + P.coef_alternative_specific_constant_for_4_driver_household_1_CAR * X.util_drivers_4p
# + P.coef_nonmand_logsum_1 * X.util_nonmand_logsum_1auto, 3:   P.coef_alternative_specific_constant_for_1_driver_household_2_CARS * X.util_drivers_1
# + P.coef_alternative_specific_constant_for_3_driver_household_2_CARS * X.util_drivers_3
# + P.coef_alternative_specific_constant_for_4_driver_household_2_CARS * X.util_drivers_4p
# + P.coef_cars2_has_18_24 * X.util_has_18_24
# + P.coef_cars2_has_25_34 * X.util_has_25_34
# + P.coef_cars2_has_65_79 * X.util_has_65_79
# + P.coef_cars2_has_80plus * X.util_has_80plus
# + P.coef_cars2_has_0_4 * X.util_has_0_4
# + P.coef_cars2_has_5_17 * X.util_has_5_17
# + P.coef_cars2_workers_1 * X.util_has_1_worker
# + P.coef_cars2_workers_2 * X.util_has_2_workers
# + P.coef_cars2_workers_3plus * X.util_has_3plus_workers
# + P.coef_household_income_15k_2_CARS * X.util_hh_income_verylow
# + P.coef_household_income_1530k_2_CARS * X.util_hh_income_low
# + P.coef_household_income_3060k_2_CARS * X.util_hh_income_mid
# + P.coef_household_income_100k_2_CARS * X.util_hh_income_veryhigh
# + P.coef_attached_2_CARS * X.util_attached
# + P.coef_intersection_density_2_CARS * X.util_intersection_density
# + P.coef_population_density_2_CARS * X.util_pop_density
# + P.coef_retail_density_2_CARS * X.util_retail_density
# + P.coef_nonmotorized_zonal_accessbility_2_CARS * X.util_nm_accessibility
# + P.coef_autotransit_zonal_accessibility_2_CARS * X.util_auto_minus_transit_accessiblity
# + P.coef_nonmand_logsum_2p * X.util_nonmand_logsum_2pauto
# + P.asc_allhhs_2_autos * X.util_asc
# + P.coef_unavailable * X.util_asc_gq
# + P.cars2_2016 * X.util_2016, 4:   P.coef_alternative_specific_constant_for_1_driver_household_3_CARS * X.util_drivers_1
# + P.coef_alternative_specific_constant_for_2_driver_household_3_CARS * X.util_drivers_2
# + P.coef_alternative_specific_constant_for_4_driver_household_3_CARS * X.util_drivers_4p
# + P.coef_cars34_has_18_24 * X.util_has_18_24
# + P.coef_cars34_has_25_34 * X.util_has_25_34
# + P.coef_cars34_has_65_79 * X.util_has_65_79
# + P.coef_cars34_has_80plus * X.util_has_80plus
# + P.coef_cars34_has_0_4 * X.util_has_0_4
# + P.coef_cars34_has_5_17 * X.util_has_5_17
# + P.coef_cars34_workers_1 * X.util_has_1_worker
# + P.coef_cars34_workers_2 * X.util_has_2_workers
# + P.coef_cars34_workers_3plus * X.util_has_3plus_workers
# + P.coef_household_income_15k_3_CARS * X.util_hh_income_verylow
# + P.coef_household_income_1530k_3_CARS * X.util_hh_income_low
# + P.coef_household_income_3060k_3_CARS * X.util_hh_income_mid
# + P.coef_household_income_100k_3_CARS * X.util_hh_income_veryhigh
# + P.coef_attached_3_CARS * X.util_attached
# + P.coef_intersection_density_3_CARS * X.util_intersection_density
# + P.coef_population_density_34_CARS * X.util_pop_density
# + P.coef_retail_density_3_CARS * X.util_retail_density
# + P.coef_nonmotorized_zonal_accessbility_3_CARS * X.util_nm_accessibility
# + P.coef_autotransit_zonal_accessibility_3_CARS * X.util_auto_minus_transit_accessiblity
# + P.coef_nonmand_logsum_2p * X.util_nonmand_logsum_2pauto
# + P.asc_allhs_3_autos * X.util_asc
# + P.coef_unavailable * X.util_asc_gq
# + P.cars3_2016 * X.util_2016, 5:   P.coef_alternative_specific_constant_for_1_driver_household_4_CARS * X.util_drivers_1
# + P.coef_alternative_specific_constant_for_2_driver_household_4_CARS * X.util_drivers_2
# + P.coef_alternative_specific_constant_for_3_driver_household_4_CARS * X.util_drivers_3
# + P.coef_cars34_has_18_24 * X.util_has_18_24
# + P.coef_cars34_has_25_34 * X.util_has_25_34
# + P.coef_cars34_has_65_79 * X.util_has_65_79
# + P.coef_cars34_has_80plus * X.util_has_80plus
# + P.coef_cars34_has_0_4 * X.util_has_0_4
# + P.coef_cars34_has_5_17 * X.util_has_5_17
# + P.coef_cars34_workers_1 * X.util_has_1_worker
# + P.coef_cars34_workers_1 * X.util_has_2_workers
# + P.coef_cars34_workers_3plus * X.util_has_3plus_workers
# + P.coef_household_income_15k_4_CARS * X.util_hh_income_verylow
# + P.coef_household_income_1530k_4_CARS * X.util_hh_income_low
# + P.coef_household_income_3060k_4_CARS * X.util_hh_income_mid
# + P.coef_household_income_100k_4_CARS * X.util_hh_income_veryhigh
# + P.coef_attached_4_CARS * X.util_attached
# + P.coef_intersection_density_4_CARS * X.util_intersection_density
# + P.coef_population_density_34_CARS * X.util_pop_density
# + P.coef_retail_density_4_CARS * X.util_retail_density
# + P.coef_nonmotorized_zonal_accessbility_4_CARS * X.util_nm_accessibility
# + P.coef_autotransit_zonal_accessibility_4_CARS * X.util_auto_minus_transit_accessiblity
# + P.coef_nonmand_logsum_2p * X.util_nonmand_logsum_2pauto
# + P.asc_allhhs_4plus_autos * X.util_asc
# + P.coef_unavailable * X.util_asc_gq
# + P.cars4_2016 * X.util_2016, 6: P.coef_cars0_workers_6 * X.util_has_1_worker})

# %%
#model.utility_co = {0: P.coef_dist_to_nearest_ext_station * X.util_dist_to_nearest_ext_station
#+ P.coef_size_of_nearest_ext_station * X.util_size_of_nearest_ext_station
#+ P.coef_part_time * X.parttime
#+ P.coef_agriculture * X.agriculture
#+ P.coef_business_srv * X.business_srv
#+ P.coef_construction * X.construction
#+ P.coef_education * X.education
#+ P.coef_entertainment * X.entertainment
#+ P.coef_food_srv * X.food_srv                   
#+ P.coef_government * X.government
#+ P.coef_healthcare * X.healthcare                   
#+ P.coef_manufacturing * X.manufacturing
#+ P.coef_mgmt_srv * X.mgmt_srv
#+ P.coef_military * X.military
#+ P.coef_retail * X.retail    
#+ P.coef_inc_lt15 * X.income_less15K
#+ P.coef_inc_15_25 * X.income_15_25 
#+ P.coef_inc_25_50 * X.income_25_50 
#+ P.coef_inc_100_150 * X.income_100_150 
#+ P.coef_inc_150_250 * X.income_150_250 
#+ P.coef_inc_250plus * X.income_250plus
#+ P.asc_external_2016 * X.year_2016         
#+ P.coef_dist_lt_2p5 * X.distance_lt_2p5                    
#+ P.asc_external_worker * X.util_asc_placeholder, 1: 0}

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.load_data()
#model.doctor(repair_ch_av="-")
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>

# %%
model.maximize_loglike(method="SLSQP", options={"maxiter": 1000})
# Out:
# <h3>Iteration 096 [Optimization terminated successfully] </h3>
# <p>Best LL = -8079.91593407802</p>
#                                value  initvalue  nullvalue  minimum  maximum  \
# asc_GQ_0_autos              2.468182        0.0        0.0      NaN      NaN
# asc_allhhs_0_autos          0.000000        0.0        0.0      0.0      0.0
# asc_allhhs_2_autos          0.000000        0.0        0.0      0.0      0.0
# asc_allhhs_4plus_autos      0.000000        0.0        0.0      0.0      0.0
# asc_allhs_3_autos           0.000000        0.0        0.0      0.0      0.0
# ...                              ...        ...        ...      ...      ...
# coef_retail_density_0_CARS  0.014187        0.0        0.0      NaN      NaN
# coef_retail_density_2_CARS  0.000000        0.0        0.0      0.0      0.0
# coef_retail_density_3_CARS -0.010902        0.0        0.0      NaN      NaN
# coef_retail_density_4_CARS -0.016816        0.0        0.0      NaN      NaN
# coef_unavailable            0.000000        0.0        0.0      0.0      0.0
#
#                             holdfast note      best
# asc_GQ_0_autos                     0       2.468182
# asc_allhhs_0_autos                 1       0.000000
# asc_allhhs_2_autos                 1       0.000000
# asc_allhhs_4plus_autos             1       0.000000
# asc_allhs_3_autos                  1       0.000000
# ...                              ...  ...       ...
# coef_retail_density_0_CARS         0       0.014187
# coef_retail_density_2_CARS         1       0.000000
# coef_retail_density_3_CARS         0      -0.010902
# coef_retail_density_4_CARS         0      -0.016816
# coef_unavailable                   1       0.000000
#
# [97 rows x 8 columns]
# C:\Users\joel.freedman\Anaconda3\envs\asim_est\lib\site-packages\larch\model\optimization.py:308: UserWarning: SLSQP may not play nicely with unbounded parameters
# if you get poor results, consider setting global bounds with model.set_cap()
#   warnings.warn( # infinite bounds # )
# ┣                x: asc_GQ_0_autos                2.468182
# ┃                   asc_allhhs_0_autos            0.000000
# ┃                   asc_allhhs_2_autos            0.000000
# ┃                   asc_allhhs_4plus_autos        0.000000
# ┃                   asc_allhs_3_autos             0.000000
# ┃                                                   ...
# ┃                   coef_retail_density_0_CARS    0.014187
# ┃                   coef_retail_density_2_CARS    0.000000
# ┃                   coef_retail_density_3_CARS   -0.010902
# ┃                   coef_retail_density_4_CARS   -0.016816
# ┃                   coef_unavailable              0.000000
# ┃                   Length: 97, dtype: float64
# ┣          loglike: -8079.91593407802
# ┣        d_loglike: asc_GQ_0_autos                0.000006
# ┃                   asc_allhhs_0_autos            0.000000
# ┃                   asc_allhhs_2_autos            0.000000
# ┃                   asc_allhhs_4plus_autos        0.000000
# ┃                   asc_allhs_3_autos             0.000000
# ┃                                                   ...
# ┃                   coef_retail_density_0_CARS   -0.027358
# ┃                   coef_retail_density_2_CARS    0.000000
# ┃                   coef_retail_density_3_CARS    0.003929
# ┃                   coef_retail_density_4_CARS    0.001730
# ┃                   coef_unavailable              0.000000
# ┃                   Length: 97, dtype: float64
# ┣              nit: 96
# ┣             nfev: 264
# ┣             njev: 96
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=42, microseconds=89399)
# ┣           method: 'SLSQP'
# ┣          n_cases: 8980
# ┣ iteration_number: 96
# ┣          logloss: 0.8997679213895345

# %% [markdown]
# ### Estimated coefficients

# %%
model.calculate_parameter_covariance()
result_dir='/projects/SANDAG/2017 On-Call Modeling Services/Area B/TO 05 - ABM3/estimation/'
model.to_xlsx(
        result_dir+"auto_ownership_007.xlsx", 
        data_statistics=True,
    )
# Out:
# <ipython-input-14-1248fb1bc527>:1: PossibleOverspecification: WARNING: Model is possibly over-specified (hessian is nearly singular).
#   model.calculate_parameter_covariance()
# C:\Users\joel.freedman\Anaconda3\envs\asim_est\lib\site-packages\larch\linalg\__init__.py:18: UserWarning: minimum eig 1.1690517424307324e-06 in general_inverse
#   warnings.warn(f"minimum eig {min_eig} in general_inverse")
# C:\Users\joel.freedman\Anaconda3\envs\asim_est\lib\site-packages\larch\util\excel.py:523: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.
#   xl = ExcelWriter(filename, engine='xlsxwriter_larch', model=model, **kwargs)

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients
result_dir = data.edb_directory/"estimated"
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_007.csv",
);

# %%
#larch.__version__

# %%
#result_dir

# %% [markdown]
# ### Write the model estimation report, including coefficient t-statistic and log likelihood

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file to the configs folder, rename it to `*_coefficients.csv`, and run ActivitySim in simulation mode.

# %%
#pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
