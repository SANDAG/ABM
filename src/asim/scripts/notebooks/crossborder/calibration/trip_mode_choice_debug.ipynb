# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
lu = pd.read_csv('data/mazs_xborder.csv')

# %%
trips = pd.read_csv('output/trace.trip_mode_choice.cargo.trip_mode_choice_annotate_trips_preprocessor.csv')

# %%
trips.tail(60)
# Out:
#                           label               value_1               value_2  \
# 30                       c_waux  -0.04856452164006818  -0.04856452164006818
# 31                      c_xfers   -0.7770323462410909   -0.7770323462410909
# 32                  c_walk_time  -0.05827742596808181  -0.05827742596808181
# 33                  c_xfers_pnr  -0.48564521640068176  -0.48564521640068176
# 34                cost_per_mile                  19.3                  19.3
# 35                    out_stops                     0                     0
# 36                     in_stops                     0                     0
# 37                    tot_stops                     0                     0
# 38                    tot_trips                     2                     2
# 39                   first_trip                  True                 False
# 40                    last_trip                 False                  True
# ...

# %%
expr_vals = pd.read_csv('output/trace.trip_mode_choice.simple_simulate.chunk_2.eval_nl.eval_utils.expression_values.csv')

# %%
expr_vals = expr_vals[expr_vals['8'] > -99999].set_index('Expression').T

# %%
expr_vals
# Out:
# Expression  c_ivt * da_time_skims  \
# 0                       -1.568119
# 1                       -1.620649
# 2                       -1.654649
# 3                       -1.682447
# 4                       -1.625090
# ..                            ...
# 219                     -0.571374
# 220                     -0.035880
# 221                     -0.064566
# 222                     -0.035880
# 223                     -0.064566
#
# Expression  @c_cost * (df.cost_per_mile * df.da_dist_skims + df.da_cost_skims)  \
# 0                                                   -3.135284
# 1                                                   -3.114989
# 2                                                   -3.238194
# 3                                                   -3.243791
# 4                                                   -3.821617
# ..                                                        ...
# 219                                                 -0.862760
# ...

# %%
expr_vals = pd.read_csv('output/trace.trip_mode_choice.simple_simulate.chunk_2.eval_nl.eval_utils.expression_value_DRIVEALONE.csv')

# %%
expr_vals = expr_vals[expr_vals['8'] > -99999]

# %%
expr_vals[(expr_vals['Expression'].str.contains('taxi_')) | (expr_vals['Expression'].str.contains('mode_is_s2'))]
# Out:
#                                            Expression    0    1    2    3  \
# 14                             c_ivt * taxi_wait_time -0.0 -0.0 -0.0 -0.0
# 15  @c_cost * ((taxi_base_fare + (df.s2_dist_skims... -0.0 -0.0 -0.0 -0.0
# 26             @df.tour_mode_is_da * taxi_ASC_tour_da -0.0 -0.0 -0.0 -0.0
# 29               @df.tour_mode_is_s2 * s2_ASC_tour_s2  0.0  0.0  0.0  0.0
# 30               @df.tour_mode_is_s2 * s3_ASC_tour_s2  0.0  0.0  0.0  0.0
# 31             @df.tour_mode_is_s2 * walk_ASC_tour_s3  0.0  0.0  0.0  0.0
# 32     @df.tour_mode_is_s2 * walk_transit_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 33             @df.tour_mode_is_s2 * taxi_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 34       @df.tour_mode_is_s2 * tnc_single_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 35       @df.tour_mode_is_s2 * tnc_shared_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 40             @df.tour_mode_is_s3 * taxi_ASC_tour_s3 -0.0 -0.0 -0.0 -0.0
# 47         @df.tour_mode_is_walk * taxi_ASC_tour_walk -0.0 -0.0 -0.0 -0.0
# ...

# %%
expr_vals = pd.read_csv('output/trace.trip_mode_choice.simple_simulate.chunk_2.eval_nl.eval_utils.expression_value_SHARED2.csv')

# %%
expr_vals = expr_vals[expr_vals['8'] > -99999]

# %%
expr_vals[(expr_vals['Expression'].str.contains('taxi_')) | (expr_vals['Expression'].str.contains('mode_is_s2'))]
# Out:
#                                            Expression    0    1    2    3  \
# 14                             c_ivt * taxi_wait_time -0.0 -0.0 -0.0 -0.0
# 15  @c_cost * ((taxi_base_fare + (df.s2_dist_skims... -0.0 -0.0 -0.0 -0.0
# 26             @df.tour_mode_is_da * taxi_ASC_tour_da -0.0 -0.0 -0.0 -0.0
# 29               @df.tour_mode_is_s2 * s2_ASC_tour_s2  0.0  0.0  0.0  0.0
# 30               @df.tour_mode_is_s2 * s3_ASC_tour_s2  0.0  0.0  0.0  0.0
# 31             @df.tour_mode_is_s2 * walk_ASC_tour_s3  0.0  0.0  0.0  0.0
# 32     @df.tour_mode_is_s2 * walk_transit_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 33             @df.tour_mode_is_s2 * taxi_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 34       @df.tour_mode_is_s2 * tnc_single_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 35       @df.tour_mode_is_s2 * tnc_shared_ASC_tour_s2 -0.0 -0.0 -0.0 -0.0
# 40             @df.tour_mode_is_s3 * taxi_ASC_tour_s3 -0.0 -0.0 -0.0 -0.0
# 47         @df.tour_mode_is_walk * taxi_ASC_tour_walk -0.0 -0.0 -0.0 -0.0
# ...

# %%
expr_vals.describe()
# Out:
#                0          1          2          3          4          5  \
# count  89.000000  89.000000  89.000000  89.000000  89.000000  89.000000
# mean   -0.059255  -0.059617  -0.061384  -0.061759  -0.067607  -0.067326
# std     0.379482   0.380033   0.392899   0.394701   0.446387   0.444204
# min    -3.135284  -3.114989  -3.238194  -3.243791  -3.821617  -3.800296
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%    -0.000000  -0.000000  -0.000000  -0.000000  -0.000000  -0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# max     0.128000   0.128000   0.128000   0.128000   0.128000   0.128000
#
#                6          7          8          9  ...        214        215  \
# count  89.000000  89.000000  89.000000  89.000000  ...  89.000000  89.000000
# mean   -0.007596  -0.007596  -0.007596  -0.007596  ...  -0.032561  -0.034336
# std     0.088975   0.088975   0.088975   0.088975  ...   0.268871   0.277794
# ...
