# %% [markdown]
# # Estimating Tour Mode Choice
#
# This notebook illustrates how to re-estimate tour and subtour mode choice for ActivitySim.  This process
# includes running ActivitySim in estimation mode to read household travel survey files and write out
# the estimation data bundles used in this notebook.  To review how to do so, please visit the other
# notebooks in this directory.

# %% [markdown]
# # Load libraries

# %%
import os
import larch  # !conda install larch -c conda-forge # for estimation
import pandas as pd
import activitysim

# %%
from larch import excel

# %% [markdown]
# We'll work in our `test` directory, where ActivitySim has saved the estimation data bundles.

# %%
os.chdir('test')

# %%
data = pd.read_csv("output/estimation_data_bundle/tour_mode_choice/tour_mode_choice_values_combined.csv")

# %% [markdown]
# # Load data and prep model for estimation

# %%
modelname = "tour_mode_choice"

from activitysim.estimation.larch import component_model
model, data = component_model(modelname, return_data=True)

# %% [markdown]
# # Review data loaded from the EDB
#
# The next step is to read the EDB, including the coefficients, model settings, utilities specification, and chooser and alternative data.

# %% [markdown]
# ### Coefficients

# %%
data.coefficients
# Out:
#                                    value constrain
# coefficient_name
# coef_one                          1.0000         F
# coef_nest_root                    1.0000         F
# coef_nest_AUTO_mandatory          0.1700         F
# coef_nest_NONMOTORIZED_mandatory  0.1700         F
# coef_wait_mandatory              -0.0300         F
# ...                                  ...       ...
# SHARED3_coef_school_nonmandatory  0.0000         F
# WALK_coef_school_nonmandatory     0.0000         F
# SHARED2_coef_cargo_nonmandatory   0.0729         F
# SHARED3_coef_cargo_nonmandatory   0.0819         F
# WALK_coef_cargo_nonmandatory      0.5089         F
#
# [62 rows x 2 columns]

# %% [markdown]
# #### Utility specification

# %%
data.spec
# Out:
#                          Label                             Description  \
# 0               util_auto_wait                          Auto Wait Time
# 1        util_auto_wait_sentri                 Auto Wait Time - Sentri
# 2                util_ped_wait                        Walk - Wait Time
# 3     util_trip_logsum_tour_da               Drive alone - Trip Logsum
# 4     util_trip_logsum_tour_s2             Shared Ride 2 - Trip Logsum
# 5     util_trip_logsum_tour_s3             Shared Ride 3 - Trip Logsum
# 6   util_trip_logsum_tour_walk                      Walk - Trip Logsum
# 7                  util_ASC_s2                     Shared Ride 2 - ASC
# 8                  util_ASC_s3                     Shared Ride 3 - ASC
# 9                util_ASC_walk                              Walk - ASC
# 10              util_sentri_s2    Crossing used Sentri - Shared Ride 2
# 11              util_sentri_s3    Crossing used Sentri - Shared Ride 3
# 12          util_visit_tour_s2              Visit Tour - Shared Ride 2
# 13          util_visit_tour_s3              Visit Tour - Shared Ride 3
# 14        util_visit_tour_walk                       Visit Tour - Walk
# 15          util_other_tour_s2              Other Tour - Shared Ride 2
# 16          util_other_tour_s3              Other Tour - Shared Ride 3
# 17        util_other_tour_walk                       Other Tour - Walk
# 18           util_calib_adj_s2  Calibration Adjustment - Shared Ride 2
# 19           util_calib_adj_s3  Calibration Adjustment - Shared Ride 3
# 20         util_calib_adj_walk           Calibration Adjustment - Walk
# 21           util_work_tour_s2               Work Tour - Shared Ride 2
# 22           util_work_tour_s3               Work Tour - Shared Ride 3
# 23         util_work_tour_walk                        Work Tour - Walk
# 24         util_school_tour_s2             School Tour - Shared Ride 2
# 25         util_school_tour_s3             School Tour - Shared Ride 3
# 26       util_school_tour_walk                      School Tour - Walk
# 27          util_cargo_tour_s2              Cargo Tour - Shared Ride 2
# 28          util_cargo_tour_s3              Cargo Tour - Shared Ride 3
# 29        util_cargo_tour_walk                       Cargo Tour - Walk
# 30           util_shop_tour_s2               Shop Tour - Shared Ride 2
# 31           util_shop_tour_s3               Shop Tour - Shared Ride 3
# 32         util_shop_tour_walk                        Shop Tour - Walk
#
#                                            Expression        DRIVEALONE  \
# 0                    (1 - sentri_crossing) * std_wait         coef_wait
# 1                       sentri_crossing * sentri_wait         coef_wait
# 2                                            ped_wait               NaN
# 3   logsum_DRIVEALONE_outbound + logsum_DRIVEALONE...  coef_trip_logsum
# 4    logsum_SHARED2_outbound + logsum_SHARED2_inbound               NaN
# 5    logsum_SHARED3_outbound + logsum_SHARED3_inbound               NaN
# 6          logsum_WALK_outbound + logsum_WALK_inbound               NaN
# 7                                                   1               NaN
# 8                                                   1               NaN
# 9                                                   1               NaN
# 10                                    sentri_crossing               NaN
# 11                                    sentri_crossing               NaN
# 12                               tour_type == 'visit'               NaN
# 13                               tour_type == 'visit'               NaN
# 14                               tour_type == 'visit'               NaN
# 15                               tour_type == 'other'               NaN
# 16                               tour_type == 'other'               NaN
# 17                               tour_type == 'other'               NaN
# 18                                                  1               NaN
# 19                                                  1               NaN
# 20                                                  1               NaN
# 21                                tour_type == 'work'               NaN
# 22                                tour_type == 'work'               NaN
# 23                                tour_type == 'work'               NaN
# 24                              tour_type == 'school'               NaN
# 25                              tour_type == 'school'               NaN
# 26                              tour_type == 'school'               NaN
# 27                               tour_type == 'cargo'               NaN
# 28                               tour_type == 'cargo'               NaN
# 29                               tour_type == 'cargo'               NaN
# 30                                tour_type == 'shop'               NaN
# 31                                tour_type == 'shop'               NaN
# 32                                tour_type == 'shop'               NaN
#
#                    SHARED2                 SHARED3                 WALK
# 0                coef_wait               coef_wait                  NaN
# 1                coef_wait               coef_wait                  NaN
# 2                      NaN                     NaN            coef_wait
# 3                      NaN                     NaN                  NaN
# 4         coef_trip_logsum                     NaN                  NaN
# 5                      NaN        coef_trip_logsum                  NaN
# 6                      NaN                     NaN     coef_trip_logsum
# 7              SHARED2_asc                     NaN                  NaN
# 8                      NaN             SHARED3_asc                  NaN
# 9                      NaN                     NaN             WALK_asc
# 10     SHARED2_coef_sentri                     NaN                  NaN
# 11                     NaN     SHARED3_coef_sentri                  NaN
# 12      SHARED2_coef_visit                     NaN                  NaN
# 13                     NaN      SHARED3_coef_visit                  NaN
# 14                     NaN                     NaN      WALK_coef_visit
# 15      SHARED2_coef_other                     NaN                  NaN
# 16                     NaN      SHARED3_coef_other                  NaN
# 17                     NaN                     NaN      WALK_coef_other
# 18  SHARED2_coef_calib_adj                     NaN                  NaN
# 19                     NaN  SHARED3_coef_calib_adj                  NaN
# 20                     NaN                     NaN  WALK_coef_calib_adj
# 21       SHARED2_coef_work                     NaN                  NaN
# 22                     NaN       SHARED3_coef_work                  NaN
# 23                     NaN                     NaN       WALK_coef_work
# 24     SHARED2_coef_school                     NaN                  NaN
# 25                     NaN     SHARED3_coef_school                  NaN
# 26                     NaN                     NaN     WALK_coef_school
# 27      SHARED2_coef_cargo                     NaN                  NaN
# 28                     NaN      SHARED3_coef_cargo                  NaN
# 29                     NaN                     NaN      WALK_coef_cargo
# 30       SHARED2_coef_shop                     NaN                  NaN
# 31                     NaN       SHARED3_coef_shop                  NaN
# 32                     NaN                     NaN       WALK_coef_shop

# %% [markdown]
# ### Chooser data

# %%
data.chooser_data
# Out:
#         model_choice override_choice  util_auto_wait  util_auto_wait_sentri  \
# tour_id
# 246             WALK            WALK             0.0                   12.9
# 618          SHARED2         SHARED2             0.0                   12.9
# 756          SHARED2      DRIVEALONE             0.0                    6.3
# 758             WALK            WALK            45.3                    0.0
# 950       DRIVEALONE      DRIVEALONE            52.8                    0.0
# ...              ...             ...             ...                    ...
# 113224       SHARED2         SHARED2            47.9                    0.0
# 113541    DRIVEALONE         SHARED2             0.0                    7.0
# 113781          WALK            WALK             0.0                   12.9
# 113857    DRIVEALONE      DRIVEALONE            52.6                    0.0
# 113901    DRIVEALONE      DRIVEALONE             0.0                    9.7
#
#          util_trip_logsum_tour_da  util_trip_logsum_tour_s2  \
# tour_id
# 246                     -7.625506                 -5.545335
# 618                     -2.211632                 -1.755930
# 756                     -1.355597                 -0.109633
# 758                     -6.438561                 -4.499242
# 950                     -5.532719                 -4.551411
# ...                           ...                       ...
# 113224                  -9.671152                 -8.686475
# 113541                  -3.958021                 -3.497978
# 113781                  -1.269312                 -0.041744
# 113857                  -0.598727                  1.609812
# 113901                  -0.324291                  1.223707
#
#          util_trip_logsum_tour_s3  util_ped_wait  util_trip_logsum_tour_walk  \
# tour_id
# 246                     -3.951179           38.8                   -2.589052
# 618                     -1.318645           38.8                   -0.470712
# 756                      0.291086           12.8                   -1.026423
# 758                     -3.604986           10.8                   -5.380926
# 950                     -3.753119           17.1                   -4.497290
# ...                           ...            ...                         ...
# 113224                  -7.907415           12.9                   -9.008587
# 113541                  -2.976279            7.7                   -1.707410
# 113781                   0.428863           38.8                    0.118229
# 113857                   2.790274           16.8                    1.152831
# 113901                   2.638933           36.3                    1.983495
#
#          util_ASC_s2  ...  logsum_SHARED3_inbound  logsum_WALK_outbound  \
# tour_id               ...
# 246                1  ...               -1.985876             -1.291829
# 618                1  ...               -0.666771             -0.368134
# 756                1  ...                0.138701             -0.506372
# 758                1  ...               -1.813668             -2.677271
# 950                1  ...               -1.931748             -2.192776
# ...              ...  ...                     ...                   ...
# 113224             1  ...               -3.940172             -4.647307
# 113541             1  ...               -1.479184             -0.882006
# 113781             1  ...                0.190405              0.063580
# 113857             1  ...                1.380744              0.582162
# 113901             1  ...                1.308521              0.999933
#
#          logsum_WALK_inbound  in_period  out_period  std_wait  sentri_wait  \
# tour_id
# 246                -1.297223         EV          AM      56.7         12.9
# 618                -0.102578         PM          AM      56.7         12.9
# 756                -0.520051         EV          MD      43.8          6.3
# 758                -2.703656         PM          MD      45.3          7.3
# 950                -2.304514         EV          EA      52.8          7.0
# ...                      ...        ...         ...       ...          ...
# 113224             -4.361280         EV          MD      47.9          5.7
# 113541             -0.825404         EV          PM      42.7          7.0
# 113781              0.054649         PM          AM      56.7         12.9
# 113857              0.570668         PM          EA      52.6         12.5
# 113901              0.983562         EV          MD      54.1          9.7
#
#          ped_wait  tour_id.1  override_choice_code
# tour_id
# 246          38.8        246                     4
# 618          38.8        618                     2
# 756          12.8        756                     1
# 758          10.8        758                     4
# 950          17.1        950                     1
# ...           ...        ...                   ...
# 113224       12.9     113224                     2
# 113541        7.7     113541                     2
# 113781       38.8     113781                     4
# 113857       16.8     113857                     1
# 113901       36.3     113901                     1
#
# [1000 rows x 253 columns]

# %% [markdown]
# # Estimate
#
# With the model setup for estimation, the next step is to estimate the model coefficients.  Make sure to use a sufficiently large enough household sample and set of zones to avoid an over-specified model, which does not have a numerically stable likelihood maximizing solution.  Larch has a built-in estimation methods including BHHH, and also offers access to more advanced general purpose non-linear optimizers in the `scipy` package, including SLSQP, which allows for bounds and constraints on parameters.  BHHH is the default and typically runs faster, but does not follow constraints on parameters.

# %%
model.load_data()
model.doctor(repair_ch_av="-")
# Out:
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# req_data does not request avail_ca or avail_co but it is set and being provided
# converting data_co to <class 'numpy.float64'>
# problem: low-variance-data-co (1 issues)
# problem: low-variance-data-co (1 issues)
# problem: low-variance-data-co (1 issues)
# problem: low-variance-data-co (1 issues)
# problem: low-variance-data-co (1 issues)
# problem: low-variance-data-co (1 issues)
# [(<larch.Model (GEV) "shop">,
#   ┣ low_variance_data_co:                   n                             example cols
#   ┃                       low_variance_co  24  util_ASC_s2, util_ASC_s3, util_ASC_walk),
#  (<larch.Model (GEV) "work">,
#   ┣ low_variance_data_co:                   n                             example cols
#   ┃                       low_variance_co  24  util_ASC_s2, util_ASC_s3, util_ASC_walk),
#  (<larch.Model (GEV) "other">,
#   ┣ low_variance_data_co:                   n                             example cols
#   ┃                       low_variance_co  24  util_ASC_s2, util_ASC_s3, util_ASC_walk),
#  (<larch.Model (GEV) "visit">,
#   ┣ low_variance_data_co:                   n                             example cols
#   ┃                       low_variance_co  24  util_ASC_s2, util_ASC_s3, util_ASC_walk),
#  (<larch.Model (GEV) "cargo">,
#   ┣ low_variance_data_co:                   n                             example cols
#   ┃                       low_variance_co  24  util_ASC_s2, util_ASC_s3, util_ASC_walk),
#  (<larch.Model (GEV) "school">,
#   ┣ low_variance_data_co:                   n                             example cols
#   ┃                       low_variance_co  24  util_ASC_s2, util_ASC_s3, util_ASC_walk)]

# %%
model.maximize_loglike(method="SLSQP", options={"maxiter": 1000})
# Out:
# <h3>Iteration 042 [Optimization terminated successfully] </h3>
# <p>Best LL = -1280.300078347854</p>
#                                         value  initvalue  nullvalue  minimum  \
# SHARED2_asc_nonmandatory            -0.665827    -1.0800        0.0      NaN
# SHARED2_coef_calib_adj_nonmandatory  0.000000     0.0000        0.0      NaN
# SHARED2_coef_cargo_nonmandatory     -0.002668     0.0729        0.0      NaN
# SHARED2_coef_other_nonmandatory      0.144895     0.0723        0.0      NaN
# SHARED2_coef_school_nonmandatory     0.000000     0.0000        0.0      NaN
# SHARED2_coef_sentri_nonmandatory     0.254594     0.4210        0.0      NaN
# SHARED2_coef_shop_nonmandatory       0.279895    -0.0608        0.0      NaN
# SHARED2_coef_visit_nonmandatory      0.151851     0.0754        0.0      NaN
# SHARED2_coef_work_nonmandatory       0.000000     0.0000        0.0      NaN
# SHARED3_asc_nonmandatory            -0.918745    -1.3520        0.0      NaN
# SHARED3_coef_calib_adj_nonmandatory  0.000000     0.0000        0.0      NaN
# SHARED3_coef_cargo_nonmandatory     -0.092072     0.0819        0.0      NaN
# SHARED3_coef_other_nonmandatory      0.345733     0.0925        0.0      NaN
# SHARED3_coef_school_nonmandatory     0.000000     0.0000        0.0      NaN
# SHARED3_coef_sentri_nonmandatory    -0.146344    -0.1550        0.0      NaN
# SHARED3_coef_shop_nonmandatory       0.161172    -0.0361        0.0      NaN
# SHARED3_coef_visit_nonmandatory      0.225122     0.0684        0.0      NaN
# SHARED3_coef_work_nonmandatory       0.000000     0.0000        0.0      NaN
# WALK_asc_nonmandatory               -1.928070    -1.9340        0.0      NaN
# WALK_coef_calib_adj_nonmandatory     0.000000     0.0000        0.0      NaN
# WALK_coef_cargo_nonmandatory         0.392551     0.5089        0.0      NaN
# WALK_coef_other_nonmandatory         0.087936     0.4702        0.0      NaN
# WALK_coef_school_nonmandatory        0.000000     0.0000        0.0      NaN
# WALK_coef_shop_nonmandatory          0.553446     0.6857        0.0      NaN
# WALK_coef_visit_nonmandatory         0.862497     0.2257        0.0      NaN
# WALK_coef_work_nonmandatory          0.000000     0.0000        0.0      NaN
# coef_nest_AUTO                       0.321491     1.0000        1.0    0.001
# coef_nest_NONMOTORIZED               1.000000     1.0000        1.0    0.001
# coef_trip_logsum_nonmandatory        0.284245     0.2140        0.0      NaN
# coef_wait_nonmandatory              -0.015163    -0.0120        0.0      NaN
# SHARED2_asc_mandatory               -0.213171    -0.5460        0.0      NaN
# SHARED2_coef_calib_adj_mandatory     0.000000     0.0000        0.0      NaN
# SHARED2_coef_cargo_mandatory         0.000000     0.0000        0.0      NaN
# SHARED2_coef_other_mandatory         0.000000     0.0000        0.0      NaN
# SHARED2_coef_school_mandatory        0.105800    -0.0868        0.0      NaN
# SHARED2_coef_sentri_mandatory        0.264030     0.1700        0.0      NaN
# SHARED2_coef_shop_mandatory          0.000000     0.0000        0.0      NaN
# SHARED2_coef_visit_mandatory         0.000000     0.0000        0.0      NaN
# SHARED2_coef_work_mandatory          0.167730     0.0275        0.0      NaN
# SHARED3_asc_mandatory               -0.559956    -0.9820        0.0      NaN
# SHARED3_coef_calib_adj_mandatory     0.000000     0.0000        0.0      NaN
# SHARED3_coef_cargo_mandatory         0.000000     0.0000        0.0      NaN
# SHARED3_coef_other_mandatory         0.000000     0.0000        0.0      NaN
# SHARED3_coef_school_mandatory        0.286167     0.0599        0.0      NaN
# SHARED3_coef_sentri_mandatory       -0.342380     0.1230        0.0      NaN
# SHARED3_coef_shop_mandatory          0.000000     0.0000        0.0      NaN
# SHARED3_coef_visit_mandatory         0.000000     0.0000        0.0      NaN
# SHARED3_coef_work_mandatory          0.289277     0.0935        0.0      NaN
# WALK_asc_mandatory                  -1.333455    -3.4000        0.0      NaN
# WALK_coef_calib_adj_mandatory        0.000000     0.0000        0.0      NaN
# WALK_coef_cargo_mandatory            0.000000     0.0000        0.0      NaN
# WALK_coef_other_mandatory            0.000000     0.0000        0.0      NaN
# WALK_coef_school_mandatory          -0.394025    -0.9567        0.0      NaN
# WALK_coef_shop_mandatory             0.000000     0.0000        0.0      NaN
# WALK_coef_visit_mandatory            0.000000     0.0000        0.0      NaN
# WALK_coef_work_mandatory             0.267671    -1.2362        0.0      NaN
# coef_trip_logsum_mandatory           0.191369     0.2000        0.0      NaN
# coef_wait_mandatory                 -0.014146    -0.0300        0.0      NaN
#
#                                      maximum  holdfast note      best
# SHARED2_asc_nonmandatory                 NaN         0      -0.665827
# SHARED2_coef_calib_adj_nonmandatory      NaN         1       0.000000
# SHARED2_coef_cargo_nonmandatory          NaN         0      -0.002668
# SHARED2_coef_other_nonmandatory          NaN         0       0.144895
# SHARED2_coef_school_nonmandatory         NaN         0       0.000000
# SHARED2_coef_sentri_nonmandatory         NaN         0       0.254594
# SHARED2_coef_shop_nonmandatory           NaN         0       0.279895
# SHARED2_coef_visit_nonmandatory          NaN         0       0.151851
# SHARED2_coef_work_nonmandatory           NaN         0       0.000000
# SHARED3_asc_nonmandatory                 NaN         0      -0.918745
# SHARED3_coef_calib_adj_nonmandatory      NaN         1       0.000000
# SHARED3_coef_cargo_nonmandatory          NaN         0      -0.092072
# SHARED3_coef_other_nonmandatory          NaN         0       0.345733
# SHARED3_coef_school_nonmandatory         NaN         0       0.000000
# SHARED3_coef_sentri_nonmandatory         NaN         0      -0.146344
# SHARED3_coef_shop_nonmandatory           NaN         0       0.161172
# SHARED3_coef_visit_nonmandatory          NaN         0       0.225122
# SHARED3_coef_work_nonmandatory           NaN         0       0.000000
# WALK_asc_nonmandatory                    NaN         0      -1.928070
# WALK_coef_calib_adj_nonmandatory         NaN         1       0.000000
# WALK_coef_cargo_nonmandatory             NaN         0       0.392551
# WALK_coef_other_nonmandatory             NaN         0       0.087936
# WALK_coef_school_nonmandatory            NaN         0       0.000000
# WALK_coef_shop_nonmandatory              NaN         0       0.553446
# WALK_coef_visit_nonmandatory             NaN         0       0.862497
# WALK_coef_work_nonmandatory              NaN         0       0.000000
# coef_nest_AUTO                           1.0         0       0.321491
# coef_nest_NONMOTORIZED                   1.0         0       1.000000
# coef_trip_logsum_nonmandatory            NaN         0       0.284245
# coef_wait_nonmandatory                   NaN         0      -0.015163
# SHARED2_asc_mandatory                    NaN         0      -0.213171
# SHARED2_coef_calib_adj_mandatory         NaN         1       0.000000
# SHARED2_coef_cargo_mandatory             NaN         0       0.000000
# SHARED2_coef_other_mandatory             NaN         0       0.000000
# SHARED2_coef_school_mandatory            NaN         0       0.105800
# SHARED2_coef_sentri_mandatory            NaN         0       0.264030
# SHARED2_coef_shop_mandatory              NaN         0       0.000000
# SHARED2_coef_visit_mandatory             NaN         0       0.000000
# SHARED2_coef_work_mandatory              NaN         0       0.167730
# SHARED3_asc_mandatory                    NaN         0      -0.559956
# SHARED3_coef_calib_adj_mandatory         NaN         1       0.000000
# SHARED3_coef_cargo_mandatory             NaN         0       0.000000
# SHARED3_coef_other_mandatory             NaN         0       0.000000
# SHARED3_coef_school_mandatory            NaN         0       0.286167
# SHARED3_coef_sentri_mandatory            NaN         0      -0.342380
# SHARED3_coef_shop_mandatory              NaN         0       0.000000
# SHARED3_coef_visit_mandatory             NaN         0       0.000000
# SHARED3_coef_work_mandatory              NaN         0       0.289277
# WALK_asc_mandatory                       NaN         0      -1.333455
# WALK_coef_calib_adj_mandatory            NaN         1       0.000000
# WALK_coef_cargo_mandatory                NaN         0       0.000000
# WALK_coef_other_mandatory                NaN         0       0.000000
# WALK_coef_school_mandatory               NaN         0      -0.394025
# WALK_coef_shop_mandatory                 NaN         0       0.000000
# WALK_coef_visit_mandatory                NaN         0       0.000000
# WALK_coef_work_mandatory                 NaN         0       0.267671
# coef_trip_logsum_mandatory               NaN         0       0.191369
# coef_wait_mandatory                      NaN         0      -0.014146
# ┣                x: SHARED2_asc_nonmandatory              -0.665827
# ┃                   SHARED2_coef_calib_adj_nonmandatory    0.000000
# ┃                   SHARED2_coef_cargo_nonmandatory       -0.002668
# ┃                   SHARED2_coef_other_nonmandatory        0.144895
# ┃                   SHARED2_coef_school_nonmandatory       0.000000
# ┃                   SHARED2_coef_sentri_nonmandatory       0.254594
# ┃                   SHARED2_coef_shop_nonmandatory         0.279895
# ┃                   SHARED2_coef_visit_nonmandatory        0.151851
# ┃                   SHARED2_coef_work_nonmandatory         0.000000
# ┃                   SHARED3_asc_nonmandatory              -0.918745
# ┃                   SHARED3_coef_calib_adj_nonmandatory    0.000000
# ┃                   SHARED3_coef_cargo_nonmandatory       -0.092072
# ┃                   SHARED3_coef_other_nonmandatory        0.345733
# ┃                   SHARED3_coef_school_nonmandatory       0.000000
# ┃                   SHARED3_coef_sentri_nonmandatory      -0.146344
# ┃                   SHARED3_coef_shop_nonmandatory         0.161172
# ┃                   SHARED3_coef_visit_nonmandatory        0.225122
# ┃                   SHARED3_coef_work_nonmandatory         0.000000
# ┃                   WALK_asc_nonmandatory                 -1.928070
# ┃                   WALK_coef_calib_adj_nonmandatory       0.000000
# ┃                   WALK_coef_cargo_nonmandatory           0.392551
# ┃                   WALK_coef_other_nonmandatory           0.087936
# ┃                   WALK_coef_school_nonmandatory          0.000000
# ┃                   WALK_coef_shop_nonmandatory            0.553446
# ┃                   WALK_coef_visit_nonmandatory           0.862497
# ┃                   WALK_coef_work_nonmandatory            0.000000
# ┃                   coef_nest_AUTO                         0.321491
# ┃                   coef_nest_NONMOTORIZED                 1.000000
# ┃                   coef_trip_logsum_nonmandatory          0.284245
# ┃                   coef_wait_nonmandatory                -0.015163
# ┃                   SHARED2_asc_mandatory                 -0.213171
# ┃                   SHARED2_coef_calib_adj_mandatory       0.000000
# ┃                   SHARED2_coef_cargo_mandatory           0.000000
# ┃                   SHARED2_coef_other_mandatory           0.000000
# ┃                   SHARED2_coef_school_mandatory          0.105800
# ┃                   SHARED2_coef_sentri_mandatory          0.264030
# ┃                   SHARED2_coef_shop_mandatory            0.000000
# ┃                   SHARED2_coef_visit_mandatory           0.000000
# ┃                   SHARED2_coef_work_mandatory            0.167730
# ┃                   SHARED3_asc_mandatory                 -0.559956
# ┃                   SHARED3_coef_calib_adj_mandatory       0.000000
# ┃                   SHARED3_coef_cargo_mandatory           0.000000
# ┃                   SHARED3_coef_other_mandatory           0.000000
# ┃                   SHARED3_coef_school_mandatory          0.286167
# ┃                   SHARED3_coef_sentri_mandatory         -0.342380
# ┃                   SHARED3_coef_shop_mandatory            0.000000
# ┃                   SHARED3_coef_visit_mandatory           0.000000
# ┃                   SHARED3_coef_work_mandatory            0.289277
# ┃                   WALK_asc_mandatory                    -1.333455
# ┃                   WALK_coef_calib_adj_mandatory          0.000000
# ┃                   WALK_coef_cargo_mandatory              0.000000
# ┃                   WALK_coef_other_mandatory              0.000000
# ┃                   WALK_coef_school_mandatory            -0.394025
# ┃                   WALK_coef_shop_mandatory               0.000000
# ┃                   WALK_coef_visit_mandatory              0.000000
# ┃                   WALK_coef_work_mandatory               0.267671
# ┃                   coef_trip_logsum_mandatory             0.191369
# ┃                   coef_wait_mandatory                   -0.014146
# ┃                   dtype: float64
# ┣          loglike: -1280.300078347854
# ┣        d_loglike: SHARED2_asc_nonmandatory               0.007694
# ┃                   SHARED2_coef_calib_adj_nonmandatory    0.000000
# ┃                   SHARED2_coef_cargo_nonmandatory        0.001093
# ┃                   SHARED2_coef_other_nonmandatory        0.007205
# ┃                   SHARED2_coef_school_nonmandatory       0.000000
# ┃                   SHARED2_coef_sentri_nonmandatory       0.003409
# ┃                   SHARED2_coef_shop_nonmandatory        -0.001503
# ┃                   SHARED2_coef_visit_nonmandatory        0.000899
# ┃                   SHARED2_coef_work_nonmandatory         0.000000
# ┃                   SHARED3_asc_nonmandatory              -0.005265
# ┃                   SHARED3_coef_calib_adj_nonmandatory    0.000000
# ┃                   SHARED3_coef_cargo_nonmandatory        0.000427
# ┃                   SHARED3_coef_other_nonmandatory        0.000045
# ┃                   SHARED3_coef_school_nonmandatory       0.000000
# ┃                   SHARED3_coef_sentri_nonmandatory       0.004829
# ┃                   SHARED3_coef_shop_nonmandatory        -0.006114
# ┃                   SHARED3_coef_visit_nonmandatory        0.000377
# ┃                   SHARED3_coef_work_nonmandatory         0.000000
# ┃                   WALK_asc_nonmandatory                  0.002077
# ┃                   WALK_coef_calib_adj_nonmandatory       0.000000
# ┃                   WALK_coef_cargo_nonmandatory           0.000431
# ┃                   WALK_coef_other_nonmandatory          -0.000330
# ┃                   WALK_coef_school_nonmandatory          0.000000
# ┃                   WALK_coef_shop_nonmandatory            0.002976
# ┃                   WALK_coef_visit_nonmandatory          -0.001000
# ┃                   WALK_coef_work_nonmandatory            0.000000
# ┃                   coef_nest_AUTO                        -0.003871
# ┃                   coef_nest_NONMOTORIZED                 0.000000
# ┃                   coef_trip_logsum_nonmandatory         -0.000737
# ┃                   coef_wait_nonmandatory                -0.017749
# ┃                   SHARED2_asc_mandatory                 -0.004806
# ┃                   SHARED2_coef_calib_adj_mandatory       0.000000
# ┃                   SHARED2_coef_cargo_mandatory           0.000000
# ┃                   SHARED2_coef_other_mandatory           0.000000
# ┃                   SHARED2_coef_school_mandatory         -0.002259
# ┃                   SHARED2_coef_sentri_mandatory          0.002060
# ┃                   SHARED2_coef_shop_mandatory            0.000000
# ┃                   SHARED2_coef_visit_mandatory           0.000000
# ┃                   SHARED2_coef_work_mandatory           -0.002547
# ┃                   SHARED3_asc_mandatory                  0.002530
# ┃                   SHARED3_coef_calib_adj_mandatory       0.000000
# ┃                   SHARED3_coef_cargo_mandatory           0.000000
# ┃                   SHARED3_coef_other_mandatory           0.000000
# ┃                   SHARED3_coef_school_mandatory          0.000669
# ┃                   SHARED3_coef_sentri_mandatory         -0.002581
# ┃                   SHARED3_coef_shop_mandatory            0.000000
# ┃                   SHARED3_coef_visit_mandatory           0.000000
# ┃                   SHARED3_coef_work_mandatory            0.001861
# ┃                   WALK_asc_mandatory                    -0.000885
# ┃                   WALK_coef_calib_adj_mandatory          0.000000
# ┃                   WALK_coef_cargo_mandatory              0.000000
# ┃                   WALK_coef_other_mandatory              0.000000
# ┃                   WALK_coef_school_mandatory             0.000854
# ┃                   WALK_coef_shop_mandatory               0.000000
# ┃                   WALK_coef_visit_mandatory              0.000000
# ┃                   WALK_coef_work_mandatory              -0.001739
# ┃                   coef_trip_logsum_mandatory             0.000325
# ┃                   coef_wait_mandatory                    0.013857
# ┃                   dtype: float64
# ┣              nit: 42
# ┣             nfev: 105
# ┣             njev: 42
# ┣           status: 0
# ┣          message: 'Optimization terminated successfully'
# ┣          success: True
# ┣     elapsed_time: datetime.timedelta(seconds=33, microseconds=535512)
# ┣           method: 'SLSQP'
# ┣          n_cases: 1000
# ┣ iteration_number: 42
# ┣          logloss: 1.280300078347854

# %% [markdown]
# ### Estimated coefficients

# %%
model.parameter_summary()
# Out:
# <style type="text/css">
# #T_913ee_ th {
#   vertical-align: top;
#   text-align: left;
# }
# #T_913ee_ td {
#   vertical-align: top;
#   text-align: left;
# }
# #T_913ee_row0_col0, #T_913ee_row0_col1, #T_913ee_row1_col0, #T_913ee_row1_col1, #T_913ee_row2_col0, #T_913ee_row2_col1, #T_913ee_row3_col0, #T_913ee_row3_col1, #T_913ee_row4_col0, #T_913ee_row4_col1, #T_913ee_row5_col0, #T_913ee_row5_col1, #T_913ee_row6_col0, #T_913ee_row6_col1, #T_913ee_row7_col0, #T_913ee_row7_col1, #T_913ee_row8_col0, #T_913ee_row8_col1, #T_913ee_row9_col0, #T_913ee_row9_col1, #T_913ee_row10_col0, #T_913ee_row10_col1, #T_913ee_row11_col0, #T_913ee_row11_col1, #T_913ee_row12_col0, #T_913ee_row12_col1, #T_913ee_row13_col0, #T_913ee_row13_col1, #T_913ee_row14_col0, #T_913ee_row14_col1, #T_913ee_row15_col0, #T_913ee_row15_col1, #T_913ee_row16_col0, #T_913ee_row16_col1, #T_913ee_row17_col0, #T_913ee_row17_col1, #T_913ee_row18_col0, #T_913ee_row18_col1, #T_913ee_row19_col0, #T_913ee_row19_col1, #T_913ee_row20_col0, #T_913ee_row20_col1, #T_913ee_row21_col0, #T_913ee_row21_col1, #T_913ee_row22_col0, #T_913ee_row22_col1, #T_913ee_row23_col0, #T_913ee_row23_col1, #T_913ee_row24_col0, #T_913ee_row24_col1, #T_913ee_row25_col0, #T_913ee_row25_col1, #T_913ee_row26_col0, #T_913ee_row26_col1, #T_913ee_row27_col0, #T_913ee_row27_col1, #T_913ee_row28_col0, #T_913ee_row28_col1, #T_913ee_row29_col0, #T_913ee_row29_col1, #T_913ee_row30_col0, #T_913ee_row30_col1, #T_913ee_row31_col0, #T_913ee_row31_col1, #T_913ee_row32_col0, #T_913ee_row32_col1, #T_913ee_row33_col0, #T_913ee_row33_col1, #T_913ee_row34_col0, #T_913ee_row34_col1, #T_913ee_row35_col0, #T_913ee_row35_col1, #T_913ee_row36_col0, #T_913ee_row36_col1, #T_913ee_row37_col0, #T_913ee_row37_col1, #T_913ee_row38_col0, #T_913ee_row38_col1, #T_913ee_row39_col0, #T_913ee_row39_col1, #T_913ee_row40_col0, #T_913ee_row40_col1, #T_913ee_row41_col0, #T_913ee_row41_col1, #T_913ee_row42_col0, #T_913ee_row42_col1, #T_913ee_row43_col0, #T_913ee_row43_col1, #T_913ee_row44_col0, #T_913ee_row44_col1, #T_913ee_row45_col0, #T_913ee_row45_col1, #T_913ee_row46_col0, #T_913ee_row46_col1, #T_913ee_row47_col0, #T_913ee_row47_col1, #T_913ee_row48_col0, #T_913ee_row48_col1, #T_913ee_row49_col0, #T_913ee_row49_col1, #T_913ee_row50_col0, #T_913ee_row50_col1, #T_913ee_row51_col0, #T_913ee_row51_col1, #T_913ee_row52_col0, #T_913ee_row52_col1, #T_913ee_row53_col0, #T_913ee_row53_col1, #T_913ee_row54_col0, #T_913ee_row54_col1, #T_913ee_row55_col0, #T_913ee_row55_col1, #T_913ee_row56_col0, #T_913ee_row56_col1, #T_913ee_row57_col0, #T_913ee_row57_col1 {
#   font-family: monospace;
# }
# </style>
# <table id="T_913ee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Value</th>
#       <th class="col_heading level0 col1" >Null Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_913ee_level0_row0" class="row_heading level0 row0" >SHARED2_asc_nonmandatory</th>
#       <td id="T_913ee_row0_col0" class="data row0 col0" >-0.666</td>
#       <td id="T_913ee_row0_col1" class="data row0 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row1" class="row_heading level0 row1" >SHARED2_coef_calib_adj_nonmandatory</th>
#       <td id="T_913ee_row1_col0" class="data row1 col0" > 0.00</td>
#       <td id="T_913ee_row1_col1" class="data row1 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row2" class="row_heading level0 row2" >SHARED2_coef_cargo_nonmandatory</th>
#       <td id="T_913ee_row2_col0" class="data row2 col0" >-0.00267</td>
#       <td id="T_913ee_row2_col1" class="data row2 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row3" class="row_heading level0 row3" >SHARED2_coef_other_nonmandatory</th>
#       <td id="T_913ee_row3_col0" class="data row3 col0" > 0.145</td>
#       <td id="T_913ee_row3_col1" class="data row3 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row4" class="row_heading level0 row4" >SHARED2_coef_school_nonmandatory</th>
#       <td id="T_913ee_row4_col0" class="data row4 col0" > 0.00</td>
#       <td id="T_913ee_row4_col1" class="data row4 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row5" class="row_heading level0 row5" >SHARED2_coef_sentri_nonmandatory</th>
#       <td id="T_913ee_row5_col0" class="data row5 col0" > 0.255</td>
#       <td id="T_913ee_row5_col1" class="data row5 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row6" class="row_heading level0 row6" >SHARED2_coef_shop_nonmandatory</th>
#       <td id="T_913ee_row6_col0" class="data row6 col0" > 0.280</td>
#       <td id="T_913ee_row6_col1" class="data row6 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row7" class="row_heading level0 row7" >SHARED2_coef_visit_nonmandatory</th>
#       <td id="T_913ee_row7_col0" class="data row7 col0" > 0.152</td>
#       <td id="T_913ee_row7_col1" class="data row7 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row8" class="row_heading level0 row8" >SHARED2_coef_work_nonmandatory</th>
#       <td id="T_913ee_row8_col0" class="data row8 col0" > 0.00</td>
#       <td id="T_913ee_row8_col1" class="data row8 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row9" class="row_heading level0 row9" >SHARED3_asc_nonmandatory</th>
#       <td id="T_913ee_row9_col0" class="data row9 col0" >-0.919</td>
#       <td id="T_913ee_row9_col1" class="data row9 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row10" class="row_heading level0 row10" >SHARED3_coef_calib_adj_nonmandatory</th>
#       <td id="T_913ee_row10_col0" class="data row10 col0" > 0.00</td>
#       <td id="T_913ee_row10_col1" class="data row10 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row11" class="row_heading level0 row11" >SHARED3_coef_cargo_nonmandatory</th>
#       <td id="T_913ee_row11_col0" class="data row11 col0" >-0.0921</td>
#       <td id="T_913ee_row11_col1" class="data row11 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row12" class="row_heading level0 row12" >SHARED3_coef_other_nonmandatory</th>
#       <td id="T_913ee_row12_col0" class="data row12 col0" > 0.346</td>
#       <td id="T_913ee_row12_col1" class="data row12 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row13" class="row_heading level0 row13" >SHARED3_coef_school_nonmandatory</th>
#       <td id="T_913ee_row13_col0" class="data row13 col0" > 0.00</td>
#       <td id="T_913ee_row13_col1" class="data row13 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row14" class="row_heading level0 row14" >SHARED3_coef_sentri_nonmandatory</th>
#       <td id="T_913ee_row14_col0" class="data row14 col0" >-0.146</td>
#       <td id="T_913ee_row14_col1" class="data row14 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row15" class="row_heading level0 row15" >SHARED3_coef_shop_nonmandatory</th>
#       <td id="T_913ee_row15_col0" class="data row15 col0" > 0.161</td>
#       <td id="T_913ee_row15_col1" class="data row15 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row16" class="row_heading level0 row16" >SHARED3_coef_visit_nonmandatory</th>
#       <td id="T_913ee_row16_col0" class="data row16 col0" > 0.225</td>
#       <td id="T_913ee_row16_col1" class="data row16 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row17" class="row_heading level0 row17" >SHARED3_coef_work_nonmandatory</th>
#       <td id="T_913ee_row17_col0" class="data row17 col0" > 0.00</td>
#       <td id="T_913ee_row17_col1" class="data row17 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row18" class="row_heading level0 row18" >WALK_asc_nonmandatory</th>
#       <td id="T_913ee_row18_col0" class="data row18 col0" >-1.93</td>
#       <td id="T_913ee_row18_col1" class="data row18 col1" > 0.00</td>
#     </tr>
#     <tr>
#       <th id="T_913ee_level0_row19" class="row_heading level0 row19" >WALK_coef_calib_adj_nonmandatory</th>
#       <td id="T_913ee_row19_col0" class="data row19 col0" > 0.0

# %% [markdown]
# # Output Estimation Results

# %%
from activitysim.estimation.larch import update_coefficients

# %%
result_dir = data.edb_directory/"estimated"

# %%
update_coefficients(
    model, data, result_dir,
    output_file=f"{modelname}_coefficients_revised.csv",
);

# %% [markdown]
# ### Write the model estimation report, including coefficient t-statistic and log likelihood

# %%
for i,model_i in enumerate(model):
    model_i.to_xlsx(
        result_dir/f"{modelname}_{i}_model_estimation.xlsx", 
        data_statistics=False,
    )
# Out:
# C:\Anaconda3\envs\asimtest\lib\site-packages\larch\util\excel.py:492: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.
#   xl = ExcelWriter(filename, engine='xlsxwriter_larch', model=model, **kwargs)

# %% [markdown]
# # Next Steps
#
# The final step is to either manually or automatically copy the `*_coefficients_revised.csv` file to the configs folder, rename it to `*_coefficients.csv`, and run ActivitySim in simulation mode.

# %%
pd.read_csv(result_dir/f"{modelname}_coefficients_revised.csv")
